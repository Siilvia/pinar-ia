# %% [markdown]
# ## Análisis del método average word2vec como sistema de recomendación de licitaciones
#
# #### input: histórico de licitaciones con traducción
# #### output: recomendación de licitaciones (content-based) basada en average word2vec
#
# ### Autor: Silvia García, Data Scientist, Grupo EVM

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import RegexpTokenizer
import re
import string
import random
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
from matplotlib import pyplot
from gensim.models import KeyedVectors
import gensim

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Lectura del df

# %%
# Reading the data
df = pd.read_csv("main_licitaciones_bbdd_idioma_traduccion.csv", error_bad_lines = False)

# %%
print('el número de licitaciones es de', len(df))
df.head(2)
# Out:
# el número de licitaciones es de 849412
#    Identificador Número de expediente  \
# 0        8689190       300/2021/00220
# 1        8723412        2021/066 PASS
#
#                                      Link licitación  \
# 0  https://contrataciondelestado.es/wps/poc?uri=d...
# 1  https://contrataciondelestado.es/wps/poc?uri=d...
#
#                                  Objeto del Contrato      Estado  \
# 0  Escuela de deportes alternativos, para el fome...    Resuelta
# 1  Suministro (Suscripción) de licencias de softw...  Adjudicada
#
#   Vigente/Anulada/Archivada Tipo de procedimiento Tramitación  \
# 0                   VIGENTE  Abierto simplificado   Ordinaria
# 1                   VIGENTE  Abierto simplificado   Ordinaria
#
#   Forma de presentación de la oferta  \
# 0                        Electrónica
# 1                        Electrónica
#
#                               Órgano de Contratación  ...  \
# 0                                 Distrito de Latina  ...
# 1  Presidencia de la Autoridad Independiente de R...  ...
#
#   Número de ofertas recibidas por licitación/lote  Resultado licitación/lote  \
# 0                                               2                 Adjudicado
# 1                                               6                 Adjudicado
#
#   Identificador Adjudicatario de la licitación/lote  \
# 0                                         G82270489
# 1                                         B84852391
#
#   Importe adjudicación sin impuestos licitación/lote Primera publicación  \
# 0                                            20000,0          2021-11-15
# 1                                           17656,32          2021-11-18
#
#   Fecha actualización Código Lugar de ejecución     Tipo Licitación  \
# 0          2021-12-30                     ES300  Licitación Directa
# 1          2021-12-30                     ES300  Licitación Directa
#
#              idioma                                          translate
# 0  Language.SPANISH  Escuela de deportes alternativos, para el fome...
# 1  Language.SPANISH  Suministro (Suscripción) de licencias de softw...
#
# [2 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Identificador', 'Número de expediente', 'Link licitación',
#        'Objeto del Contrato', 'Estado', 'Vigente/Anulada/Archivada',
#        'Tipo de procedimiento', 'Tramitación',
#        'Forma de presentación de la oferta', 'Órgano de Contratación',
#        'Tipo de contrato', 'Lote', 'CPV', 'Sistema de contratación',
#        'Directiva de aplicación', 'Subcontratación permitida',
#        'Valor estimado del contrato', 'Presupuesto base sin impuestos',
#        'Con Adjudicatario', 'Número de ofertas recibidas por licitación/lote',
#        'Resultado licitación/lote',
#        'Identificador Adjudicatario de la licitación/lote',
#        'Importe adjudicación sin impuestos licitación/lote',
#        'Primera publicación', 'Fecha actualización',
#        'Código Lugar de ejecución', 'Tipo Licitación', 'idioma', 'translate'],
#       dtype='object')

# %% [markdown]
# ### 2. Preprocesamiento de texto
#
# La idea es eliminar símbolos, tildes y caracteres extraños, así como stop words. Pasar a minúscula todas las letras.

# %%
df['analisis'] = df['translate'] + ' ' + df['Tipo de procedimiento'] + ' ' \
+ ' ' + df['Órgano de Contratación'] + ' ' + df['Tipo de contrato']

# %%
df['analisis'] = df['analisis'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df['analisis'] = df['analisis'].str.replace(r'\w*\d\w*','')

# %%
def _removeNonAscii(s):
    return "".join(i for i in s if  ord(i)<128)

def make_lower_case(text):
    return text.lower()

def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("spanish"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

df['cleaned'] = df['analisis'].apply(_removeNonAscii)

df['cleaned'] = df.cleaned.apply(func = make_lower_case)
df['cleaned'] = df.cleaned.apply(func = remove_stop_words)
df['cleaned'] = df.cleaned.apply(func = remove_punctuation)
df['cleaned'] = df.cleaned.apply(func = remove_html)

# %%
# Creamos el corpus

corpus = []
for words in df['cleaned']:
    corpus.append(words.split())

# %%
corpus
# Out:
# [['escuela',
#   'deportes',
#   'alternativos',
#   'fomento',
#   'deporte',
#   'vida',
#   'sana',
#   'cultura',
#   'dirigido',
#   'jovenes',
#   'barrio',
#   'cano',
#   'roto',
#   'distrito',
#   'latina',
#   'abierto',
#   'simplificado',
#   'distrito',
#   'latina',
#   'servicios'],
#  ['suministro',
#   'suscripcion',
#   'licencias',
#   'software',
#   'ofimatico',
#   'autoridad',
#   'independiente',
#   'responsabilidad',
#   'fiscal',
#   'aai',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'autoridad',
#   'independiente',
#   'responsabilidad',
#   'fiscal',
#   'suministros'],
#  ['instalacion',
#   'envolvente',
#   'ayuntamiento',
#   'rena',
#   'abierto',
#   'simplificado',
#   'area',
#   'fomento',
#   'diputacion',
#   'provincial',
#   'badajoz',
#   'obras'],
#  ['prestacion',
#   'servicios',
#   'mantenimiento',
#   'material',
#   'rodante',
#   'motor',
#   'direccion',
#   'servicios',
#   'logisticos',
#   'adif',
#   'abierto',
#   'adif',
#   'consejo',
#   'administracion',
#   'servicios'],
#  ['prestacion',
#   'servicios',
#   'mantenimiento',
#   'material',
#   'rodante',
#   'motor',
#   'direccion',
#   'servicios',
#   'logisticos',
#   'adif',
#   'abierto',
#   'adif',
#   'consejo',
#   'administracion',
#   'servicios'],
#  ['prestacion',
#   'servicios',
#   'mantenimiento',
#   'material',
#   'rodante',
#   'motor',
#   'direccion',
#   'servicios',
#   'logisticos',
#   'adif',
#   'abierto',
#   'adif',
#   'consejo',
#   'administracion',
#   'servicios'],
#  ['pedido',
#   'acuerdo',
#   'marco',
#   'prestacion',
#   'servicios',
#   'diseno',
#   'realizacion',
#   'asesoria',
#   'comunicacion',
#   'eventos',
#   'presentaciones',
#   'rr',
#   'ss',
#   'actos',
#   'protocolarios',
#   'direccion',
#   'comunicacion',
#   'reputacion',
#   'corporativa',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'adif',
#   'presidencia',
#   'servicios'],
#  ['proyecto',
#   'mercave',
#   'compra',
#   'publica',
#   'tecnologia',
#   'innovadora',
#   'ejes',
#   'ancho',
#   'variable',
#   'mercancias',
#   'incorporando',
#   'innovacion',
#   'fabricacion',
#   'suministro',
#   'puesta',
#   'servicio',
#   'abierto',
#   'adif',
#   'presidencia',
#   'suministros'],
#  ['ejecucion',
#   'obras',
#   'proyecto',
#   'constructivo',
#   'nuevo',
#   'edificio',
#   'viajeros',
#   'estacion',
#   'santiago',
#   'compostela',
#   'abierto',
#   'adif',
#   'alta',
#   'velocidad',
#   'consejo',
#   'administracion',
#   'obras'],
#  ['servicio',
#   'soporte',
#   'viajeros',
#   'operadores',
#   'frontera',
#   'sistema',
#   'declaracion',
#   'viajeros',
#   'internacionales',
#   'negociado',
#   'publicidad',
#   'secretaria',
#   'general',
#   'salud',
#   'digital',
#   'informacion',
#   'innovacion',
#   'sistema',
#   'nacional',
#   'salud',
#   'servicios'],
#  ['servicios',
#   'asistencia',
#   'tecnica',
#   'operacion',
#   'explotacion',
#   'registro',
#   'vacunaciones',
#   'ministerio',
#   'sanidad',
#   'negociado',
#   'publicidad',
#   'direccion',
#   'general',
#   'salud',
#   'publica',
#   'calidad',
#   'innovacion',
#   'servicios'],
#  ['servicio',
#   'limpieza',
#   'centros',
#   'adscritos',
#   'consejeria',
#   'industria',
#   'empleo',
#   'promocion',
#   'economica',
#   'abierto',
#   'consejeria',
#   'industria',
#   'empleo',
#   'promocion',
#   'economica',
#   'servicios'],
#  ['servicio',
#   'limpieza',
#   'centros',
#   'adscritos',
#   'consejeria',
#   'industria',
#   'empleo',
#   'promocion',
#   'economica',
#   'abierto',
#   'consejeria',
#   'industria',
#   'empleo',
#   'promocion',
#   'economica',
#   'servicios'],
#  ['servicio',
#   'asistencia',
#   'tecnica',
#   'evaluacion',
#   'operacion',
#   'sistema',
#   'declaracion',
#   'viajeros',
#   'internacionales',
#   'negociado',
#   'publicidad',
#   'secretaria',
#   'general',
#   'salud',
#   'digital',
#   'informacion',
#   'innovacion',
#   'sistema',
#   'nacional',
#   'salud',
#   'servicios'],
#  ['contrato',
#   'suministro',
#   'matriales',
#   'obras',
#   'pfea',
#   'lotes',
#   'procedimiento',
#   'abierto',
#   'tramitacion',
#   'urgente',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'cortegana',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'matriales',
#   'obras',
#   'pfea',
#   'lotes',
#   'procedimiento',
#   'abierto',
#   'tramitacion',
#   'urgente',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'cortegana',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'matriales',
#   'obras',
#   'pfea',
#   'lotes',
#   'procedimiento',
#   'abierto',
#   'tramitacion',
#   'urgente',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'cortegana',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'matriales',
#   'obras',
#   'pfea',
#   'lotes',
#   'procedimiento',
#   'abierto',
#   'tramitacion',
#   'urgente',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'cortegana',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'matriales',
#   'obras',
#   'pfea',
#   'lotes',
#   'procedimiento',
#   'abierto',
#   'tramitacion',
#   'urgente',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'cortegana',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'matriales',
#   'obras',
#   'pfea',
#   'lotes',
#   'procedimiento',
#   'abierto',
#   'tramitacion',
#   'urgente',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'cortegana',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'matriales',
#   'obras',
#   'pfea',
#   'lotes',
#   'procedimiento',
#   'abierto',
#   'tramitacion',
#   'urgente',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'cortegana',
#   'suministros'],
#  ['servicio',
#   'mantenimiento',
#   'reglamentario',
#   'aparatos',
#   'equipos',
#   'sistemas',
#   'empleados',
#   'proteccion',
#   'contraincendios',
#   'deteccion',
#   'gases',
#   'centro',
#   'desarrollo',
#   'tecnologias',
#   'cubillos',
#   'sil',
#   'leon',
#   'fundacion',
#   'ciudad',
#   'energia',
#   'ciuden',
#   'f',
#   's',
#   'p',
#   'abierto',
#   'simplificado',
#   'direccion',
#   'general',
#   'fundacion',
#   'ciudad',
#   'energia',
#   'servicios'],
#  ['obras',
#   'plan',
#   'mejora',
#   'reparacion',
#   'caminos',
#   'municipales',
#   'termino',
#   'municipal',
#   'rambla',
#   'fase',
#   'i',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'rambla',
#   'obras'],
#  ['obras',
#   'plan',
#   'mejora',
#   'reparacion',
#   'caminos',
#   'municipales',
#   'termino',
#   'municipal',
#   'rambla',
#   'fase',
#   'i',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'rambla',
#   'obras'],
#  ['acuerdo',
#   'marco',
#   'regir',
#   'contratacion',
#   'suministro',
#   'sillas',
#   'tableros',
#   'incluido',
#   'transporte',
#   'montaje',
#   'desmontaje',
#   'actos',
#   'conforman',
#   'programacion',
#   'organismo',
#   'autonomo',
#   'fiestas',
#   'actividades',
#   'recreativas',
#   'mediante',
#   'procedimiento',
#   'negociado',
#   'publicidad',
#   'tramitacion',
#   'ordinaria',
#   'negociado',
#   'publicidad',
#   'consejo',
#   'rector',
#   'organismo',
#   'autonomo',
#   'fiestas',
#   'actividades',
#   'recreativas',
#   'excmo',
#   'ayuntamiento',
#   'santa',
#   'cruz',
#   'tenerife',
#   'suministros'],
#  ['adquisicion',
#   'ordenador',
#   'portatil',
#   'superior',
#   'licencia',
#   'sistema',
#   'operativo',
#   'ampliacion',
#   'almacenamiento',
#   'ssd',
#   'estacion',
#   'biologica',
#   'do',
#   'ana',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'csic',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['suministro',
#   'licencia',
#   'mantenimiento',
#   'sistema',
#   'qualipoc',
#   'medida',
#   'redes',
#   'moviles',
#   'deteccion',
#   'fallos',
#   'etsi',
#   'ingenieria',
#   'sistemas',
#   'telecomunicacion',
#   'universidad',
#   'politecnica',
#   'madrid',
#   'negociado',
#   'publicidad',
#   'rectorado',
#   'universidad',
#   'politecnica',
#   'madrid',
#   'suministros'],
#  ['asesoramiento',
#   'juridico',
#   'defensa',
#   'juicios',
#   'ayuntamiento',
#   'posadas',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'posadas',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'asistencia',
#   'sanitaria',
#   'ambulatoria',
#   'tratamiento',
#   'inicial',
#   'sucesivo',
#   'remision',
#   'servicios',
#   'medicos',
#   'propios',
#   'mutua',
#   'ambito',
#   'territorial',
#   'comunidades',
#   'autonomas',
#   'aragon',
#   'rioja',
#   'extremadura',
#   'madrid',
#   'baleares',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'asistencia',
#   'sanitaria',
#   'ambulatoria',
#   'tratamiento',
#   'inicial',
#   'sucesivo',
#   'remision',
#   'servicios',
#   'medicos',
#   'propios',
#   'mutua',
#   'ambito',
#   'territorial',
#   'comunidades',
#   'autonomas',
#   'aragon',
#   'rioja',
#   'extremadura',
#   'madrid',
#   'baleares',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'asistencia',
#   'sanitaria',
#   'ambulatoria',
#   'tratamiento',
#   'inicial',
#   'sucesivo',
#   'remision',
#   'servicios',
#   'medicos',
#   'propios',
#   'mutua',
#   'ambito',
#   'territorial',
#   'comunidades',
#   'autonomas',
#   'aragon',
#   'rioja',
#   'extremadura',
#   'madrid',
#   'baleares',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'asistencia',
#   'sanitaria',
#   'ambulatoria',
#   'tratamiento',
#   'inicial',
#   'sucesivo',
#   'remision',
#   'servicios',
#   'medicos',
#   'propios',
#   'mutua',
#   'ambito',
#   'territorial',
#   'comunidades',
#   'autonomas',
#   'aragon',
#   'rioja',
#   'extremadura',
#   'madrid',
#   'baleares',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'asistencia',
#   'sanitaria',
#   'ambulatoria',
#   'tratamiento',
#   'inicial',
#   'sucesivo',
#   'remision',
#   'servicios',
#   'medicos',
#   'propios',
#   'mutua',
#   'ambito',
#   'territorial',
#   'comunidades',
#   'autonomas',
#   'aragon',
#   'rioja',
#   'extremadura',
#   'madrid',
#   'baleares',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'asistencia',
#   'sanitaria',
#   'ambulatoria',
#   'tratamiento',
#   'inicial',
#   'sucesivo',
#   'remision',
#   'servicios',
#   'medicos',
#   'propios',
#   'mutua',
#   'ambito',
#   'territorial',
#   'comunidades',
#   'autonomas',
#   'aragon',
#   'rioja',
#   'extremadura',
#   'madrid',
#   'baleares',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'epi',
#   's',
#   'caracter',
#   'general',
#   'destino',
#   'buques',
#   'dependencia',
#   'armada',
#   'abierto',
#   'director',
#   'gestion',
#   'economica',
#   'jefatura',
#   'apoyo',
#   'logistico',
#   'armada',
#   'suministros'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'epi',
#   's',
#   'caracter',
#   'general',
#   'destino',
#   'buques',
#   'dependencia',
#   'armada',
#   'abierto',
#   'director',
#   'gestion',
#   'economica',
#   'jefatura',
#   'apoyo',
#   'logistico',
#   'armada',
#   'suministros'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'epi',
#   's',
#   'caracter',
#   'general',
#   'destino',
#   'buques',
#   'dependencia',
#   'armada',
#   'abierto',
#   'director',
#   'gestion',
#   'economica',
#   'jefatura',
#   'apoyo',
#   'logistico',
#   'armada',
#   'suministros'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'epi',
#   's',
#   'caracter',
#   'general',
#   'destino',
#   'buques',
#   'dependencia',
#   'armada',
#   'abierto',
#   'director',
#   'gestion',
#   'economica',
#   'jefatura',
#   'apoyo',
#   'logistico',
#   'armada',
#   'suministros'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'epi',
#   's',
#   'caracter',
#   'general',
#   'destino',
#   'buques',
#   'dependencia',
#   'armada',
#   'abierto',
#   'director',
#   'gestion',
#   'economica',
#   'jefatura',
#   'apoyo',
#   'logistico',
#   'armada',
#   'suministros'],
#  ['prestacion',
#   'servicio',
#   'representacion',
#   'escenica',
#   'espectaculo',
#   'denominado',
#   'gueule',
#   'dours',
#   'boca',
#   'oso',
#   'dentro',
#   'programacion',
#   'actividad',
#   'cultural',
#   'cabalgata',
#   'reyes',
#   'en',
#   'adelante',
#   'actividad',
#   'cultural',
#   'actividad',
#   'celebrar',
#   'enero',
#   'horas',
#   'aprox',
#   'tramo',
#   'final',
#   'recorrido',
#   'cabalgata',
#   'plaza',
#   'colon',
#   'plaza',
#   'cibeles',
#   'negociado',
#   'publicidad',
#   'madrid',
#   'destino',
#   'cultura',
#   'turismo',
#   'negocio',
#   's',
#   'a',
#   'servicios'],
#  ['contratacion',
#   'servicios',
#   'representacion',
#   'espectaculo',
#   'teatro',
#   'calle',
#   'les',
#   'giraffes',
#   'parte',
#   'programacion',
#   'actividad',
#   'cultural',
#   'cabalgata',
#   'reyes',
#   'negociado',
#   'publicidad',
#   'madrid',
#   'destino',
#   'cultura',
#   'turismo',
#   'negocio',
#   's',
#   'a',
#   'servicios'],
#  ['procedimiento',
#   'contratacion',
#   'lotes',
#   'mantenimiento',
#   'oracle',
#   'renovacion',
#   'licencias',
#   'citrix',
#   'renovacion',
#   'licencia',
#   'antispam',
#   'corporativo',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'caceres',
#   'suministros'],
#  ['procedimiento',
#   'contratacion',
#   'lotes',
#   'mantenimiento',
#   'oracle',
#   'renovacion',
#   'licencias',
#   'citrix',
#   'renovacion',
#   'licencia',
#   'antispam',
#   'corporativo',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'caceres',
#   'suministros'],
#  ['procedimiento',
#   'contratacion',
#   'lotes',
#   'mantenimiento',
#   'oracle',
#   'renovacion',
#   'licencias',
#   'citrix',
#   'renovacion',
#   'licencia',
#   'antispam',
#   'corporativo',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'caceres',
#   'suministros'],
#  ['servicios',
#   'creacion',
#   'representacion',
#   'artistica',
#   'espectaculo',
#   'elesphantasia',
#   'dentro',
#   'programacion',
#   'actividad',
#   'cabalgata',
#   'reyes',
#   'abierto',
#   'madrid',
#   'destino',
#   'cultura',
#   'turismo',
#   'negocio',
#   's',
#   'a',
#   'servicios'],
#  ['solucion',
#   'integral',
#   'digitalizacion',
#   'copia',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'gerencia',
#   'infraestructures',
#   'i',
#   'serveis',
#   'telecom',
#   'i',
#   'certificacio',
#   's',
#   'a',
#   'u',
#   'suministros'],
#  ['servicios',
#   'limpieza',
#   'instalaciones',
#   'instituto',
#   'corcho',
#   'madera',
#   'carbon',
#   'vegetal',
#   'icmc',
#   'perteneciente',
#   'centro',
#   'investigaciones',
#   'cientificas',
#   'tecnologicas',
#   'extremadura',
#   'cicytex',
#   'abierto',
#   'direccion',
#   'centro',
#   'investigaciones',
#   'cientificas',
#   'tecnologicas',
#   'extremadura',
#   'cicytex',
#   'servicios'],
#  ['contratacion',
#   'certamen',
#   'vehiculo',
#   'clasico',
#   'epoca',
#   'celebrara',
#   'palacio',
#   'ferias',
#   'congresos',
#   'malaga',
#   'fycma',
#   'negociado',
#   'publicidad',
#   'direccion',
#   'general',
#   'palacio',
#   'ferias',
#   'congresos',
#   'malaga',
#   'privado'],
#  ['renovacion',
#   'licencias',
#   'vmware',
#   'usuarios',
#   'ayuntamiento',
#   'caceres',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'caceres',
#   'suministros'],
#  ['subministro',
#   'instalacion',
#   'cinco',
#   'puntos',
#   'informacion',
#   'turistica',
#   'exteriores',
#   'dentro',
#   'da',
#   'zona',
#   'urbana',
#   'sada',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'sada',
#   'suministros'],
#  ['acondicionamiento',
#   'repavimentacion',
#   'calle',
#   'san',
#   'salvador',
#   'entorno',
#   'abierto',
#   'pleno',
#   'ayuntamiento',
#   'frontera',
#   'obras'],
#  ['servicio',
#   'limpieza',
#   'ceip',
#   'tigaday',
#   'banos',
#   'publicos',
#   'maceta',
#   'tigaday',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'frontera',
#   'servicios'],
#  ['mantenimiento',
#   'servicio',
#   'digitalizacion',
#   'documentos',
#   'maz',
#   'm',
#   'c',
#   's',
#   's',
#   'reservado',
#   'centros',
#   'especiales',
#   'empleo',
#   'iniciativa',
#   'social',
#   'empresas',
#   'insercion',
#   'animo',
#   'lucro',
#   'abierto',
#   'gerencia',
#   'maz',
#   'mutua',
#   'accidentes',
#   'trabajo',
#   'enfermedades',
#   'profesionales',
#   'seguridad',
#   'social',
#   'servicios'],
#  ['proyecto',
#   'reordenacion',
#   'ronda',
#   'pizarra',
#   'fase',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'caceres',
#   'obras'],
#  ['suministro',
#   'instalacion',
#   'cogeneradores',
#   'autoconsumo',
#   'biogas',
#   'generacion',
#   'energia',
#   'electrica',
#   'edar',
#   'benidorm',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'benidorm',
#   'suministros'],
#  ['suministro',
#   'alumbrados',
#   'ornamentos',
#   'servicios',
#   'montaje',
#   'mantenimiento',
#   'desmontaje',
#   'alumbrado',
#   'fiestas',
#   'navidenas',
#   'municipio',
#   'arico',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'villa',
#   'arico',
#   'suministros'],
#  ['servicios',
#   'gestion',
#   'centro',
#   'tratamiento',
#   'ambulatorio',
#   'personas',
#   'drogodependientes',
#   'baza',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'baza',
#   'servicios'],
#  ['contrato',
#   'servicio',
#   'consultoria',
#   'diseno',
#   'ejecucion',
#   'plan',
#   'comunicacion',
#   'estrategia',
#   'edusi',
#   'benidorm',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'benidorm',
#   'servicios'],
#  ['contratacion',
#   'suministro',
#   'sillas',
#   'tableros',
#   'incluido',
#   'transporte',
#   'montaje',
#   'desmontaje',
#   'actos',
#   'conforman',
#   'programacion',
#   'organismo',
#   'autonomo',
#   'fiestas',
#   'actividades',
#   'recreativas',
#   'abierto',
#   'consejo',
#   'rector',
#   'organismo',
#   'autonomo',
#   'fiestas',
#   'actividades',
#   'recreativas',
#   'excmo',
#   'ayuntamiento',
#   'santa',
#   'cruz',
#   'tenerife',
#   'suministros'],
#  ['contratacion',
#   'servicio',
#   'asistencia',
#   'sanitaria',
#   'hospitales',
#   'pacientes',
#   'afectos',
#   'dano',
#   'neurologico',
#   'comunidad',
#   'autonoma',
#   'aragon',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['colaboracion',
#   'asistencia',
#   'tecnica',
#   'intervencion',
#   'general',
#   'carm',
#   'realizacion',
#   'trabajos',
#   'auditoria',
#   'operaciones',
#   'previstas',
#   'articulo',
#   'reglamento',
#   'ue',
#   'parlamento',
#   'europeo',
#   'consejo',
#   'establecen',
#   'disposiciones',
#   'comunes',
#   'relativas',
#   'fondos',
#   'estructurales',
#   'inversion',
#   'europeos',
#   'lotes',
#   'abierto',
#   'consejeria',
#   'economia',
#   'hacienda',
#   'administracion',
#   'digital',
#   'servicios'],
#  ['colaboracion',
#   'asistencia',
#   'tecnica',
#   'intervencion',
#   'general',
#   'carm',
#   'realizacion',
#   'trabajos',
#   'auditoria',
#   'operaciones',
#   'previstas',
#   'articulo',
#   'reglamento',
#   'ue',
#   'parlamento',
#   'europeo',
#   'consejo',
#   'establecen',
#   'disposiciones',
#   'comunes',
#   'relativas',
#   'fondos',
#   'estructurales',
#   'inversion',
#   'europeos',
#   'lotes',
#   'abierto',
#   'consejeria',
#   'economia',
#   'hacienda',
#   'administracion',
#   'digital',
#   'servicios'],
#  ['colaboracion',
#   'asistencia',
#   'tecnica',
#   'intervencion',
#   'general',
#   'carm',
#   'realizacion',
#   'trabajos',
#   'auditoria',
#   'operaciones',
#   'previstas',
#   'articulo',
#   'reglamento',
#   'ue',
#   'parlamento',
#   'europeo',
#   'consejo',
#   'establecen',
#   'disposiciones',
#   'comunes',
#   'relativas',
#   'fondos',
#   'estructurales',
#   'inversion',
#   'europeos',
#   'lotes',
#   'abierto',
#   'consejeria',
#   'economia',
#   'hacienda',
#   'administracion',
#   'digital',
#   'servicios'],
#  ['colaboracion',
#   'asistencia',
#   'tecnica',
#   'intervencion',
#   'general',
#   'carm',
#   'realizacion',
#   'trabajos',
#   'auditoria',
#   'operaciones',
#   'previstas',
#   'articulo',
#   'reglamento',
#   'ue',
#   'parlamento',
#   'europeo',
#   'consejo',
#   'establecen',
#   'disposiciones',
#   'comunes',
#   'relativas',
#   'fondos',
#   'estructurales',
#   'inversion',
#   'europeos',
#   'lotes',
#   'abierto',
#   'consejeria',
#   'economia',
#   'hacienda',
#   'administracion',
#   'digital',
#   'servicios'],
#  ['arrendamiento',
#   'vivienda',
#   'municipal',
#   'sita',
#   'fresno',
#   'cantespino',
#   'calle',
#   'santo',
#   'domingo',
#   'abierto',
#   'pleno',
#   'ayuntamiento',
#   'fresno',
#   'cantespino',
#   'patrimonial'],
#  ['suministro',
#   'impresoras',
#   'equipos',
#   'multifuncion',
#   'television',
#   'publica',
#   'canarias',
#   's',
#   'a',
#   'radio',
#   'publica',
#   'canarias',
#   'modalidad',
#   'arrendamiento',
#   'mantenimiento',
#   'abierto',
#   'simplificado',
#   'television',
#   'publica',
#   'canarias',
#   's',
#   'a',
#   'suministros'],
#  ['servicios',
#   'asistencia',
#   'tecnica',
#   'definicion',
#   'ejecucion',
#   'plan',
#   'continuidad',
#   'sistemas',
#   'ministerio',
#   'asuntos',
#   'exteriores',
#   'union',
#   'europea',
#   'cooperacion',
#   'abierto',
#   'simplificado',
#   'direccion',
#   'general',
#   'servicio',
#   'exterior',
#   'servicios'],
#  ['servicios',
#   'tramitacion',
#   'tecnica',
#   'expedientes',
#   'consultoria',
#   'proyectos',
#   'obras',
#   'mejora',
#   'infraestructuras',
#   'gestionadas',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'aclm',
#   'se',
#   'abierto',
#   'presidencia',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'servicios'],
#  ['servicios',
#   'tramitacion',
#   'tecnica',
#   'expedientes',
#   'consultoria',
#   'proyectos',
#   'obras',
#   'mejora',
#   'infraestructuras',
#   'gestionadas',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'aclm',
#   'se',
#   'abierto',
#   'presidencia',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'servicios'],
#  ['servicios',
#   'tramitacion',
#   'tecnica',
#   'expedientes',
#   'consultoria',
#   'proyectos',
#   'obras',
#   'mejora',
#   'infraestructuras',
#   'gestionadas',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'aclm',
#   'se',
#   'abierto',
#   'presidencia',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'servicios'],
#  ['servicios',
#   'tramitacion',
#   'tecnica',
#   'expedientes',
#   'consultoria',
#   'proyectos',
#   'obras',
#   'mejora',
#   'infraestructuras',
#   'gestionadas',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'aclm',
#   'se',
#   'abierto',
#   'presidencia',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'servicios'],
#  ['servicios',
#   'tramitacion',
#   'tecnica',
#   'expedientes',
#   'consultoria',
#   'proyectos',
#   'obras',
#   'mejora',
#   'infraestructuras',
#   'gestionadas',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'aclm',
#   'se',
#   'abierto',
#   'presidencia',
#   'infraestructuras',
#   'agua',
#   'castilla',
#   'la',
#   'mancha',
#   'servicios'],
#  ['suministro',
#   'microestaciones',
#   'base',
#   'mbs',
#   'mejora',
#   'cobertura',
#   'rescan',
#   'negociado',
#   'publicidad',
#   'viceconsejeria',
#   'administraciones',
#   'publicas',
#   'transparencia',
#   'suministros'],
#  ['servicio',
#   'mantenimiento',
#   'instalaciones',
#   'proteccion',
#   'incendios',
#   'edificios',
#   'zonas',
#   'dependientes',
#   'universidad',
#   'autonoma',
#   'madrid',
#   'abierto',
#   'rectorado',
#   'universidad',
#   'autonoma',
#   'madrid',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['servicio',
#   'escuelas',
#   'deportivas',
#   'municipales',
#   'abierto',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'requena',
#   'servicios'],
#  ['mellora',
#   'capa',
#   'rodaxe',
#   'caminos',
#   'das',
#   'parroquias',
#   'san',
#   'fiz',
#   'queixeiro',
#   'vilacha',
#   'val',
#   'xestoso',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'monfero',
#   'obras'],
#  ['desarrollos',
#   'evolutivos',
#   'diversos',
#   'sistemas',
#   'informacion',
#   'soporte',
#   'gestion',
#   'explotacion',
#   'informacion',
#   'fondos',
#   'europeos',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'intervencion',
#   'general',
#   'administracion',
#   'servicios'],
#  ['servicio',
#   'seguros',
#   'ayuntamiento',
#   'albolote',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'albolote',
#   'servicios'],
#  ['servicios',
#   'desarrollo',
#   'mantenimiento',
#   'aplicaciones',
#   'informaticas',
#   'diversos',
#   'ambitos',
#   'instituto',
#   'mayores',
#   'servicios',
#   'sociales',
#   'imserso',
#   'abierto',
#   'direccion',
#   'general',
#   'instituto',
#   'mayores',
#   'servicios',
#   'sociales',
#   'servicios'],
#  ['mellora',
#   'capa',
#   'rodache',
#   'caminos',
#   'da',
#   'parroquia',
#   'san',
#   'fiz',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'monfero',
#   'obras'],
#  ['agente',
#   'comercial',
#   'venta',
#   'canales',
#   'brasil',
#   'abierto',
#   'direccion',
#   'compras',
#   'corporacion',
#   'radio',
#   'television',
#   'espanola',
#   's',
#   'a',
#   'servicios'],
#  ['contratacion',
#   'obras',
#   'conservacion',
#   'mantenimiento',
#   'red',
#   'provincial',
#   'carreteras',
#   'caminos',
#   'diputacion',
#   'cordoba',
#   'periodo',
#   'minimo',
#   'dos',
#   'anos',
#   'maximo',
#   'tres',
#   'anos',
#   'mas',
#   'estructurado',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'diputacion',
#   'provincial',
#   'cordoba',
#   'obras'],
#  ['contratacion',
#   'obras',
#   'conservacion',
#   'mantenimiento',
#   'red',
#   'provincial',
#   'carreteras',
#   'caminos',
#   'diputacion',
#   'cordoba',
#   'periodo',
#   'minimo',
#   'dos',
#   'anos',
#   'maximo',
#   'tres',
#   'anos',
#   'mas',
#   'estructurado',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'diputacion',
#   'provincial',
#   'cordoba',
#   'obras'],
#  ['contratacion',
#   'obras',
#   'conservacion',
#   'mantenimiento',
#   'red',
#   'provincial',
#   'carreteras',
#   'caminos',
#   'diputacion',
#   'cordoba',
#   'periodo',
#   'minimo',
#   'dos',
#   'anos',
#   'maximo',
#   'tres',
#   'anos',
#   'mas',
#   'estructurado',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'diputacion',
#   'provincial',
#   'cordoba',
#   'obras'],
#  ['contratacion',
#   'obras',
#   'conservacion',
#   'mantenimiento',
#   'red',
#   'provincial',
#   'carreteras',
#   'caminos',
#   'diputacion',
#   'cordoba',
#   'periodo',
#   'minimo',
#   'dos',
#   'anos',
#   'maximo',
#   'tres',
#   'anos',
#   'mas',
#   'estructurado',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'diputacion',
#   'provincial',
#   'cordoba',
#   'obras'],
#  ['contratacion',
#   'obras',
#   'conservacion',
#   'mantenimiento',
#   'red',
#   'provincial',
#   'carreteras',
#   'caminos',
#   'diputacion',
#   'cordoba',
#   'periodo',
#   'minimo',
#   'dos',
#   'anos',
#   'maximo',
#   'tres',
#   'anos',
#   'mas',
#   'estructurado',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'diputacion',
#   'provincial',
#   'cordoba',
#   'obras'],
#  ['servicio',
#   'transporte',
#   'participantes',
#   'programa',
#   'deporte',
#   'edad',
#   'escolar',
#   'temporada',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'toledo',
#   'servicios'],
#  ['servicio',
#   'transporte',
#   'participantes',
#   'programa',
#   'deporte',
#   'edad',
#   'escolar',
#   'temporada',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'toledo',
#   'servicios'],
#  ['servicio',
#   'transporte',
#   'participantes',
#   'programa',
#   'deporte',
#   'edad',
#   'escolar',
#   'temporada',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'toledo',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'transporte',
#   'pacientes',
#   'centros',
#   'asistenciales',
#   'fremap',
#   'mutua',
#   'colaboradora',
#   'seguridad',
#   'social',
#   'cantabria',
#   'galicia',
#   'abierto',
#   'director',
#   'gerente',
#   'fremap',
#   'servicios'],
#  ['objeto',
#   'contrato',
#   'sera',
#   'suscripcion',
#   'parte',
#   'ayuntamiento',
#   'polizas',
#   'seguro',
#   'configuran',
#   'programa',
#   'seguros',
#   'cobertura',
#   'riesgos',
#   'descritos',
#   'pliegos',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'rosario',
#   'servicios'],
#  ['objeto',
#   'contrato',
#   'sera',
#   'suscripcion',
#   'parte',
#   'ayuntamiento',
#   'polizas',
#   'seguro',
#   'configuran',
#   'programa',
#   'seguros',
#   'cobertura',
#   'riesgos',
#   'descritos',
#   'pliegos',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'rosario',
#   'servicios'],
#  ['objeto',
#   'contrato',
#   'sera',
#   'suscripcion',
#   'parte',
#   'ayuntamiento',
#   'polizas',
#   'seguro',
#   'configuran',
#   'programa',
#   'seguros',
#   'cobertura',
#   'riesgos',
#   'descritos',
#   'pliegos',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'rosario',
#   'servicios'],
#  ['objeto',
#   'contrato',
#   'sera',
#   'suscripcion',
#   'parte',
#   'ayuntamiento',
#   'polizas',
#   'seguro',
#   'configuran',
#   'programa',
#   'seguros',
#   'cobertura',
#   'riesgos',
#   'descritos',
#   'pliegos',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'rosario',
#   'servicios'],
#  ['objeto',
#   'contrato',
#   'sera',
#   'suscripcion',
#   'parte',
#   'ayuntamiento',
#   'polizas',
#   'seguro',
#   'configuran',
#   'programa',
#   'seguros',
#   'cobertura',
#   'riesgos',
#   'descritos',
#   'pliegos',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'rosario',
#   'servicios'],
#  ['objeto',
#   'contrato',
#   'sera',
#   'suscripcion',
#   'parte',
#   'ayuntamiento',
#   'polizas',
#   'seguro',
#   'configuran',
#   'programa',
#   'seguros',
#   'cobertura',
#   'riesgos',
#   'descritos',
#   'pliegos',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'rosario',
#   'servicios'],
#  ['obras',
#   'ejecucioon',
#   'proyecto',
#   'instalaciones',
#   'seguridad',
#   'comunicaciones',
#   'ferroviarias',
#   'fase',
#   'provisional',
#   'definitiva',
#   'lineas',
#   'red',
#   'convencional',
#   'obras',
#   'estructura',
#   'accesos',
#   'estacion',
#   'sagrera',
#   'on',
#   'abierto',
#   'adif',
#   'alta',
#   'velocidad',
#   'consejo',
#   'administracion',
#   'obras'],
#  ['adquisicion',
#   'ordenador',
#   'portatil',
#   'superior',
#   'licencia',
#   'sistema',
#   'operativo',
#   'ampliacion',
#   'almacenamiento',
#   'ssd',
#   'estacion',
#   'biologica',
#   'do',
#   'ana',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'csic',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['adquisicion',
#   'ordenador',
#   'portatil',
#   'superior',
#   'licencia',
#   'sistema',
#   'operativo',
#   'ampliacion',
#   'almacenamiento',
#   'ssd',
#   'estacion',
#   'biologica',
#   'do',
#   'ana',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'csic',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['actualizacion',
#   'licencias',
#   'virtualizacion',
#   'escritorios',
#   'aplicaciones',
#   'departamento',
#   'informatica',
#   'tributaria',
#   'agencia',
#   'estatal',
#   'administracion',
#   'tributaria',
#   'servicio',
#   'gestion',
#   'economica',
#   'a',
#   'e',
#   'a',
#   't',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['suministro',
#   'plataforma',
#   'elevadora',
#   'remolcable',
#   'servicio',
#   'zona',
#   'confederacion',
#   'hidrografica',
#   'guadiana',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'confederacion',
#   'hidrografica',
#   'guadiana',
#   'suministros'],
#  ['suministro',
#   'licencias',
#   'actualizacion',
#   'entorno',
#   'virtualizacion',
#   'vmware',
#   'bne',
#   'biblioteca',
#   'nacional',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['adquisicion',
#   'monitor',
#   'pulgadas',
#   'estacion',
#   'biologica',
#   'do',
#   'ana',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'agencia',
#   'estatal',
#   'consejo',
#   'superior',
#   'investigaciones',
#   'cientificas',
#   'csic',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['suministro',
#   'licencias',
#   'uso',
#   'soporte',
#   'tecnico',
#   'gestor',
#   'contenidos',
#   'magnolia',
#   'mefp',
#   'lote',
#   'subdireccion',
#   'general',
#   'tecnologias',
#   'informacion',
#   'comunicaciones',
#   'mefp',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['servicio',
#   'formacion',
#   'cursos',
#   'talleres',
#   'centros',
#   'sociales',
#   'mayores',
#   'municipio',
#   'murcia',
#   'mediante',
#   'tres',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'murcia',
#   'servicios'],
#  ['servicio',
#   'formacion',
#   'cursos',
#   'talleres',
#   'centros',
#   'sociales',
#   'mayores',
#   'municipio',
#   'murcia',
#   'mediante',
#   'tres',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'murcia',
#   'servicios'],
#  ['servicio',
#   'formacion',
#   'cursos',
#   'talleres',
#   'centros',
#   'sociales',
#   'mayores',
#   'municipio',
#   'murcia',
#   'mediante',
#   'tres',
#   'lotes',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'murcia',
#   'servicios'],
#  ['adquisicion',
#   'ordenadores',
#   'sobremesa',
#   'superiores',
#   'raid',
#   'instituto',
#   'nacional',
#   'gestion',
#   'sanitaria',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'direccion',
#   'general',
#   'racionalizacion',
#   'centralizacion',
#   'contratacion',
#   'junta',
#   'contratacion',
#   'centralizada',
#   'suministros'],
#  ['casar',
#   'caceres',
#   'mejora',
#   'infraestructura',
#   'electrica',
#   'municipal',
#   'mie',
#   'cuadro',
#   'mando',
#   'zona',
#   'centro',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'caceres',
#   'obras'],
#  ['suministro',
#   'implantacion',
#   'sistema',
#   'telefonia',
#   'voz',
#   'ip',
#   'edificio',
#   'sede',
#   'cabildo',
#   'insular',
#   'gomera',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'cabildo',
#   'insular',
#   'gomera',
#   'suministros'],
#  ['contratacion',
#   'plataforma',
#   'administracion',
#   'electronica',
#   'espublico',
#   'gestiona',
#   'negociado',
#   'publicidad',
#   'presidencia',
#   'mancomunidad',
#   'servicios',
#   'provincia',
#   'huelva',
#   'servicios'],
#  ['suministro',
#   'herramientas',
#   'servicio',
#   'prevencion',
#   'extincion',
#   'incendios',
#   'salvamento',
#   'lotes',
#   'abierto',
#   'simplificado',
#   'organos',
#   'directivos',
#   'ayuntamiento',
#   'sevilla',
#   'suministros'],
#  ['suministro',
#   'herramientas',
#   'servicio',
#   'prevencion',
#   'extincion',
#   'incendios',
#   'salvamento',
#   'lotes',
#   'abierto',
#   'simplificado',
#   'organos',
#   'directivos',
#   'ayuntamiento',
#   'sevilla',
#   'suministros'],
#  ['contrato',
#   'servicio',
#   'adjudicacion',
#   'poliza',
#   'responsabilidad',
#   'autoridades',
#   'personal',
#   'servicio',
#   'ayuntamiento',
#   'castilleja',
#   'cuesta',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'castilleja',
#   'cuesta',
#   'servicios'],
#  ['concertacion',
#   'operacion',
#   'prestamo',
#   'largo',
#   'plazo',
#   'importe',
#   'millon',
#   'euros',
#   'financiacion',
#   'obras',
#   'construccion',
#   'pabellon',
#   'cubierto',
#   'abierto',
#   'alcaldia',
#   'ayuntamiento',
#   'sierra',
#   'yeguas',
#   'privado'],
#  ['combustible',
#   'vehiculos',
#   'automocion',
#   'adscritos',
#   'servicio',
#   'concejalia',
#   'limpieza',
#   'viaria',
#   'rsu',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'orihuela',
#   'suministros'],
#  ['combustible',
#   'vehiculos',
#   'automocion',
#   'adscritos',
#   'servicio',
#   'concejalia',
#   'limpieza',
#   'viaria',
#   'rsu',
#   'abierto',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'orihuela',
#   'suministros'],
#  ['suministro',
#   'tarjetas',
#   'electronicas',
#   'traccion',
#   'tranvias',
#   'metropolitano',
#   'tenerife',
#   's',
#   'a',
#   'negociado',
#   'publicidad',
#   'consejo',
#   'administracion',
#   'metropolitano',
#   'tenerife',
#   's',
#   'a',
#   'suministros'],
#  ['contratacion',
#   'servicio',
#   'correduria',
#   'seguros',
#   'poliza',
#   'seguro',
#   'responsabilidad',
#   'civil',
#   'general',
#   'grupo',
#   'correos',
#   'responsabilidad',
#   'transportistas',
#   's',
#   'e',
#   'correos',
#   'telegrafos',
#   's',
#   'a',
#   'normas',
#   'internas',
#   'subdireccion',
#   'compras',
#   'sociedad',
#   'estatal',
#   'correos',
#   'telegrafos',
#   's',
#   'a',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'correduria',
#   'seguros',
#   'poliza',
#   'seguro',
#   'responsabilidad',
#   'civil',
#   'general',
#   'grupo',
#   'correos',
#   'responsabilidad',
#   'transportistas',
#   's',
#   'e',
#   'correos',
#   'telegrafos',
#   's',
#   'a',
#   'normas',
#   'internas',
#   'subdireccion',
#   'compras',
#   'sociedad',
#   'estatal',
#   'correos',
#   'telegrafos',
#   's',
#   'a',
#   'servicios'],
#  ['contrato',
#   'suministro',
#   'materiales',
#   'servicio',
#   'alquiler',
#   'pala',
#   'mecanica',
#   'camion',
#   'basculante',
#   'conductor',
#   'actuaciones',
#   'reposicion',
#   'mantenimiento',
#   'vias',
#   'ayto',
#   'sauzal',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'sauzal',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'materiales',
#   'servicio',
#   'alquiler',
#   'pala',
#   'mecanica',
#   'camion',
#   'basculante',
#   'conductor',
#   'actuaciones',
#   'reposicion',
#   'mantenimiento',
#   'vias',
#   'ayto',
#   'sauzal',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'sauzal',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'materiales',
#   'servicio',
#   'alquiler',
#   'pala',
#   'mecanica',
#   'camion',
#   'basculante',
#   'conductor',
#   'actuaciones',
#   'reposicion',
#   'mantenimiento',
#   'vias',
#   'ayto',
#   'sauzal',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'sauzal',
#   'suministros'],
#  ['construccion',
#   'fosas',
#   'dobles',
#   'zona',
#   'b',
#   'cementerio',
#   'municipal',
#   'padre',
#   'jesus',
#   'espinardo',
#   'murcia',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'murcia',
#   'obras'],
#  ['contrato',
#   'suministro',
#   'lotes',
#   'materiales',
#   'deportivos',
#   'anos',
#   'ayuntamiento',
#   'castilleja',
#   'cuesta',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'castilleja',
#   'cuesta',
#   'suministros'],
#  ['contrato',
#   'suministro',
#   'lotes',
#   'materiales',
#   'deportivos',
#   'anos',
#   'ayuntamiento',
#   'castilleja',
#   'cuesta',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'castilleja',
#   'cuesta',
#   'suministros'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'pescados',
#   'mariscos',
#   'moluscos',
#   'frescos',
#   'lonja',
#   'parador',
#   'santiago',
#   'diciembre',
#   'enero',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'paradores',
#   'turismo',
#   'espana',
#   's',
#   'm',
#   'e',
#   's',
#   'a',
#   'suministros'],
#  ['suministro',
#   'vehiculos',
#   'renting',
#   'gran',
#   'telescopio',
#   'canarias',
#   's',
#   'a',
#   'grantecan',
#   'siguiendo',
#   'condiciones',
#   'directrices',
#   'descritas',
#   'ppt',
#   'motivacion',
#   'principal',
#   'renting',
#   'dotar',
#   'grantecan',
#   'vehiculos',
#   'suficientes',
#   'aseguren',
#   'movilidad',
#   'personal',
#   'sedes',
#   'abierto',
#   'direccion',
#   'general',
#   'gran',
#   'telescopio',
#   'canarias',
#   's',
#   'a',
#   'suministros'],
#  ['servicios',
#   'auxiliares',
#   'atencion',
#   'venta',
#   'cliente',
#   'abonado',
#   'atencion',
#   'personalizada',
#   'reclamaciones',
#   'fundacion',
#   'teatro',
#   'real',
#   'f',
#   's',
#   'p',
#   'abierto',
#   'direccion',
#   'general',
#   'fundacion',
#   'teatro',
#   'real',
#   'servicios'],
#  ['contrato',
#   'gestion',
#   'desarrollo',
#   'servicios',
#   'autonomia',
#   'personas',
#   'atencion',
#   'socioterapeutica',
#   'cuidadores',
#   'personas',
#   'situacion',
#   'dependencia',
#   'abierto',
#   'instituto',
#   'aragones',
#   'servicios',
#   'sociales',
#   'iass',
#   'servicios'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'pescados',
#   'mariscos',
#   'moluscos',
#   'frescos',
#   'lonja',
#   'parador',
#   'nerja',
#   'diciembre',
#   'enero',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'paradores',
#   'turismo',
#   'espana',
#   's',
#   'm',
#   'e',
#   's',
#   'a',
#   'suministros'],
#  ['mantenimiento',
#   'licencias',
#   'sealsign',
#   'servicio',
#   'extremeno',
#   'salud',
#   'abierto',
#   'direccion',
#   'general',
#   'planificacion',
#   'economica',
#   'servicios'],
#  ['contratacion',
#   'emergencia',
#   'servicio',
#   'limpieza',
#   'lavanderia',
#   'cpr',
#   'tenderina',
#   'centro',
#   'adscrito',
#   'organismo',
#   'autonomo',
#   'establecimientos',
#   'residenciales',
#   'ancianos',
#   'asturias',
#   'negociado',
#   'publicidad',
#   'organismo',
#   'autonomo',
#   'establecimientos',
#   'residenciales',
#   'ancianos',
#   'asturias',
#   'servicios'],
#  ['acuerdo',
#   'marco',
#   'suministro',
#   'pescados',
#   'mariscos',
#   'moluscos',
#   'frescos',
#   'lonja',
#   'parador',
#   'mazagon',
#   'diciembre',
#   'enero',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'paradores',
#   'turismo',
#   'espana',
#   's',
#   'm',
#   'e',
#   's',
#   'a',
#   'suministros'],
#  ['acuerdo',
#   'marco',
#   'ejecucion',
#   'obras',
#   'redes',
#   'abastecimiento',
#   'aguas',
#   'saneamiento',
#   'riego',
#   'municipio',
#   'puerto',
#   'real',
#   'abierto',
#   'consejo',
#   'administracion',
#   'grupo',
#   'energetico',
#   'puerto',
#   'real',
#   's',
#   'a',
#   'obras'],
#  ['contrato',
#   'suministro',
#   'bajo',
#   'modalidad',
#   'arrendamiento',
#   'opcion',
#   'compra',
#   'renting',
#   'dos',
#   'vehiculos',
#   'nuevos',
#   'servicio',
#   'policia',
#   'local',
#   'ayuntamiento',
#   'pobla',
#   'vallbona',
#   'valencia',
#   'incluido',
#   'mantenimiento',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'pobla',
#   'vallbona',
#   'suministros'],
#  ['objeto',
#   'acuerdo',
#   'marco',
#   'consiste',
#   'establecer',
#   'requisitos',
#   'criterios',
#   'condiciones',
#   'regir',
#   'futuras',
#   'contrataciones',
#   'servicios',
#   'relativas',
#   'prestacion',
#   'acorde',
#   'lotes',
#   'establezcan',
#   'servicio',
#   'defensa',
#   'direccion',
#   'letrada',
#   'cualquier',
#   'procedimiento',
#   'judicial',
#   'jurisdiccion',
#   'contencioso',
#   'administrativa',
#   'actuaciones',
#   'promuevan',
#   'caracter',
#   'preliminar',
#   'proceso',
#   'aquellos',
#   'asuntos',
#   'competencia',
#   'gull',
#   'objeto',
#   'litis',
#   'verse',
#   'actuaciones',
#   'enmarcadas',
#   'expedientes',
#   'tramitan',
#   'organismo',
#   'siempre',
#   'declinado',
#   'representacion',
#   'asesoria',
#   'juridica',
#   'ayuntamiento',
#   'laguna',
#   'ambito',
#   'jurisdiccion',
#   'contencioso',
#   'administrativa',
#   'ello',
#   'conformidad',
#   'estipulado',
#   'apartados',
#   'ppt',
#   'cuenta',
#   'que',
#   'tal',
#   'establece',
#   'articulo',
#   'reglamento',
#   'organico',
#   'excmo',
#   'ayuntamiento',
#   'laguna',
#   'asesoria',
#   'juridica',
#   'organo',
#   'encargado',
#   'asistencia',
#   'juridica',
#   'ayuntamiento',
#   'organismos',
#   'publicos',
#   'mientras',
#   'apartado',
#   'quinto',
#   'tal',
#   'norma',
#   'contempla',
#   'funciones',
#   'representacion',
#   'defensa',
#   'juicio',
#   'encomendaran',
# ...
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'impartir',
#   'itinerarios',
#   'formativos',
#   'provincia',
#   'ciudad',
#   'real',
#   'ocho',
#   'jornadas',
#   'networking',
#   'marco',
#   'programa',
#   'promueve',
#   'vi',
#   'abierto',
#   'presidencia',
#   'diputacion',
#   'provincial',
#   'ciudad',
#   'real',
#   'servicios'],
#  ['seguro',
#   'responsabilidad',
#   'civil',
#   'profesional',
#   'arquitectos',
#   'ingenieros',
#   'ingenieras',
#   'servicio',
#   'joquitectura',
#   'lontaminanteimas',
#   'abierto',
#   'simplificado',
#   'imas',
#   'gerencia',
#   'privado'],
#  ['prestacion',
#   'do',
#   'servizo',
#   'asistencia',
#   'xuridica',
#   'centro',
#   'infomacion',
#   'as',
#   'mulleres',
#   'cim',
#   'do',
#   'concello',
#   'da',
#   'estrada',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'concello',
#   'da',
#   'estrada',
#   'servicios'],
#  ['suministro',
#   'cascos',
#   'proteccion',
#   'cabeza',
#   'protectores',
#   'auditivos',
#   'pantallas',
#   'faciales',
#   'adaptables',
#   'casco',
#   'personal',
#   'emuasa',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'gerencia',
#   'empresa',
#   'municipal',
#   'aguas',
#   'saneamiento',
#   'murcia',
#   's',
#   'a',
#   'suministros'],
#  ['seguro',
#   'danos',
#   'materiales',
#   'responsabilidad',
#   'civil',
#   'accidentes',
#   'abierto',
#   'presidencia',
#   'institucion',
#   'ferial',
#   'badajoz',
#   'privado'],
#  ['seguro',
#   'danos',
#   'materiales',
#   'responsabilidad',
#   'civil',
#   'accidentes',
#   'abierto',
#   'presidencia',
#   'institucion',
#   'ferial',
#   'badajoz',
#   'privado'],
#  ['contrato',
#   'coordinacion',
#   'servicios',
#   'auxiliares',
#   'necesarios',
#   'desarrollo',
#   'actos',
#   'programados',
#   'feria',
#   'valencia',
#   'ocasion',
#   'celebracion',
#   'feria',
#   'expojove',
#   'cabalgata',
#   'reyes',
#   'abierto',
#   'simplificado',
#   'concejalia',
#   'delegada',
#   'contratacion',
#   'ajuntament',
#   'valencia',
#   'servicios'],
#  ['suministro',
#   'banderas',
#   'institucionales',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'suministros'],
#  ['suministro',
#   'banderas',
#   'institucionales',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'suministros'],
#  ['suministro',
#   'banderas',
#   'institucionales',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'suministros'],
#  ['suministro',
#   'banderas',
#   'institucionales',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'abierto',
#   'simplificado',
#   'presidencia',
#   'autoridad',
#   'portuaria',
#   'baleares',
#   'suministros'],
#  ['obras',
#   'ejecucion',
#   'campo',
#   'fultol',
#   'campo',
#   'polivalente',
#   'futbol',
#   'playa',
#   'voley',
#   'playa',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'ayuntamiento',
#   'daimiel',
#   'obras'],
#  ['mejora',
#   'seguridad',
#   'vial',
#   'ampliacion',
#   'tramo',
#   'acera',
#   'carretera',
#   'lp',
#   'lp',
#   'san',
#   'antonio',
#   't',
#   'm',
#   'brena',
#   'baja',
#   'exp',
#   'inversion',
#   'carreteras',
#   'abierto',
#   'simplificado',
#   'consejeria',
#   'insular',
#   'area',
#   'infraestructuras',
#   'innovacion',
#   'nuevas',
#   'tecnologias',
#   'ordenacion',
#   'territorio',
#   'cabildo',
#   'insular',
#   'palma',
#   'obras'],
#  ['contrato',
#   'administrativo',
#   'obra',
#   'objeto',
#   'reorganizacion',
#   'acceso',
#   'via',
#   'servicio',
#   'tf',
#   'barrio',
#   'nieves',
#   'abierto',
#   'concejalia',
#   'delegada',
#   'hacienda',
#   'adeje',
#   'obras'],
#  ['contratacion',
#   'servicio',
#   'limpieza',
#   'edificios',
#   'dependencias',
#   'zonas',
#   'dependientes',
#   'instalaciones',
#   'instituto',
#   'municipal',
#   'desarrollo',
#   'economico',
#   'empleo',
#   'cordoba',
#   'imdeec',
#   'abierto',
#   'consejo',
#   'rector',
#   'instituto',
#   'municipal',
#   'desarrollo',
#   'economico',
#   'empleo',
#   'cordoba',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'diseno',
#   'grafico',
#   'revision',
#   'tecnica',
#   'preimpresion',
#   'distintos',
#   'elementos',
#   'comunicacion',
#   'promocion',
#   'palacio',
#   'ferias',
#   'congresos',
#   'malaga',
#   'fycma',
#   'abierto',
#   'direccion',
#   'general',
#   'palacio',
#   'ferias',
#   'congresos',
#   'malaga',
#   'servicios'],
#  ['contratacion',
#   'servicio',
#   'diseno',
#   'grafico',
#   'revision',
#   'tecnica',
#   'preimpresion',
#   'distintos',
#   'elementos',
#   'comunicacion',
#   'promocion',
#   'palacio',
#   'ferias',
#   'congresos',
#   'malaga',
#   'fycma',
#   'abierto',
#   'direccion',
#   'general',
#   'palacio',
#   'ferias',
#   'congresos',
#   'malaga',
#   'servicios'],
#  ['suministro',
#   'filtros',
#   'anillo',
#   'radiaciones',
#   'ionizantes',
#   'termoluminiscencia',
#   'tld',
#   'porta',
#   'dosimetro',
#   'anillo',
#   'centro',
#   'nacional',
#   'dosimetria',
#   'abierto',
#   'simplificado',
#   'gerencia',
#   'centro',
#   'nacional',
#   'dosimetria',
#   'instituto',
#   'nacional',
#   'gestion',
#   'sanitaria',
#   'suministros'],
#  ['suministro',
#   'filtros',
#   'anillo',
#   'radiaciones',
#   'ionizantes',
#   'termoluminiscencia',
#   'tld',
#   'porta',
#   'dosimetro',
#   'anillo',
#   'centro',
#   'nacional',
#   'dosimetria',
#   'abierto',
#   'simplificado',
#   'gerencia',
#   'centro',
#   'nacional',
#   'dosimetria',
#   'instituto',
#   'nacional',
#   'gestion',
#   'sanitaria',
#   'suministros'],
#  ['servicio',
#   'vigilancia',
#   'sede',
#   'centro',
#   'nacional',
#   'medios',
#   'proteccion',
#   'insst',
#   'o',
#   'a',
#   'm',
#   'p',
#   'sevilla',
#   'abierto',
#   'instituto',
#   'nacional',
#   'seguridad',
#   'salud',
#   'trabajo',
#   'o',
#   'a',
#   'm',
#   'p',
#   'insst',
#   'servicios'],
#  ['suministro',
#   'vehiculo',
#   'electrico',
#   'puro',
#   'bateria',
#   'servicio',
#   'policia',
#   'local',
#   'ayuntamiento',
#   'moraleja',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'moraleja',
#   'suministros'],
#  ['ejecucion',
#   'obras',
#   'proyecto',
#   'iniciativa',
#   'puerto',
#   'verde',
#   'ajardinamiento',
#   'viario',
#   'fase',
#   'ii',
#   'abierto',
#   'simplificado',
#   'autoridad',
#   'portuaria',
#   'malaga',
#   'obras'],
#  ['suministro',
#   'propiedad',
#   'vehiculo',
#   'tipo',
#   'pick',
#   'up',
#   'gancho',
#   'cubas',
#   'servicios',
#   'limpieza',
#   'espacios',
#   'publicos',
#   'mantenimiento',
#   'urbano',
#   'parques',
#   'jardines',
#   'cargo',
#   'subvencion',
#   'diputacion',
#   'sevilla',
#   'correspondiente',
#   'plan',
#   'contigo',
#   'programa',
#   'municipal',
#   'especifico',
#   'adquisicion',
#   'maquinaria',
#   'mantenimiento',
#   'urbano',
#   'vehiculos',
#   'limpieza',
#   'viaria',
#   'abierto',
#   'simplificado',
#   'junta',
#   'gobierno',
#   'local',
#   'ayuntamiento',
#   'alcala',
#   'guadaira',
#   'suministros'],
#  ['acondicionamento',
#   'do',
#   'edificio',
#   'servicios',
#   'da',
#   'feira',
#   'do',
#   'trece',
#   'actuacion',
#   'comprendida',
#   'plan',
#   'provincial',
#   'cooperacion',
#   'as',
#   'obras',
#   'servizos',
#   'competencia',
#   'municipal',
#   'plan',
#   'unico',
#   'concellos',
#   'pos',
#   'adicional',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'naron',
#   'obras'],
#  ['suministro',
#   'energia',
#   'electrica',
#   'edificios',
#   'instalaciones',
#   'servicio',
#   'salud',
#   'islas',
#   'baleares',
#   'primer',
#   'semestre',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'contratacion',
#   'centralizada',
#   'suministro',
#   'energia',
#   'electrica',
#   'edificios',
#   'instalaciones',
#   'administracion',
#   'comunidad',
#   'autonoma',
#   'islas',
#   'baleares',
#   'sector',
#   'publico',
#   'instrumental',
#   'cc',
#   'am',
#   'derivado',
#   'acuerdo',
#   'marco',
#   'servicio',
#   'salud',
#   'illes',
#   'balears',
#   'suministros'],
#  ['mantenimiento',
#   'preventivo',
#   'normativo',
#   'correctivo',
#   'dos',
#   'centros',
#   'maniobra',
#   'medida',
#   'cmm',
#   'abierto',
#   'consorcio',
#   'transportes',
#   'mallorca',
#   'servicios'],
#  ['mantenimiento',
#   'preventivo',
#   'normativo',
#   'correctivo',
#   'dos',
#   'centros',
#   'maniobra',
#   'medida',
#   'cmm',
#   'abierto',
#   'consorcio',
#   'transportes',
#   'mallorca',
#   'servicios'],
#  ['arrendamiento',
#   'inmueble',
#   'solar',
#   'sito',
#   'c',
#   'luis',
#   'vidal',
#   'monovar',
#   'aparcamiento',
#   'publico',
#   'secundariamente',
#   'necesidades',
#   'municipales',
#   'como',
#   'ejemplo',
#   'instalacion',
#   'mercadillo',
#   'ferias',
#   'etc',
#   'negociado',
#   'publicidad',
#   'alcaldia',
#   'ayuntamiento',
#   'monovar',
#   'privado'],
#  ['reurbanizacion',
#   'villa',
#   'aljarafe',
#   'alto',
#   'aljarafe',
#   'plaza',
#   'escuela',
#   'sevillana',
#   'termino',
#   'municipal',
#   'tomares',
#   'sevilla',
#   'abierto',
#   'simplificado',
#   'alcaldia',
#   'ayuntamiento',
#   'tomares',
#   'obras'],
#  ['servicio',
#   'mantenimiento',
#   'integral',
#   'instalaciones',
#   'infraestructuras',
#   'edificios',
#   'dependientes',
#   'gerencia',
#   'baleares',
#   'abierto',
#   'simplificado',
#   'servicio',
#   'salud',
#   'illes',
#   'balears',
#   'servicios'],
#  ['compra',
#   'herbicida',
#   'campana',
#   'fumigacion',
#   'ciudad',
#   'algeciras',
#   'abierto',
#   'simplificado',
#   'consejeria',
#   'delegada',
#   'actividades',
#   'limpieza',
#   'gestion',
#   's',
#   'a',
#   'suministros'],
#  ['suministro',
#   'tubos',
#   'polietileno',
#   'alta',
#   'densidad',
#   'tubos',
#   'policloruro',
#   'vinilo',
#   'pvc',
#   'u',
#   'abierto',
#   'consejeria',
#   'delegada',
#   'consorcio',
#   'abastecimiento',
#   'aguas',
#   'fuerteventura',
#   'suministros'],
#  ['suministro',
#   'guante',
#   'examen',
#   'vinilo',
#   'elastomero',
#   'ambidiestro',
#   'polvo',
#   'esteril',
#   'varias',
#   'tallas',
#   'restringido',
#   'direccion',
#   'gerencia',
#   'hospital',
#   'universitario',
#   'gran',
#   'canaria',
#   'doctor',
#   'negrin',
#   'suministros'],
#  ['suministro',
#   'tubos',
#   'polietileno',
#   'alta',
#   'densidad',
#   'tubos',
#   'policloruro',
#   'vinilo',
#   'pvc',
#   'u',
#   'abierto',
#   'consejeria',
#   'delegada',
#   'consorcio',
#   'abastecimiento',
#   'aguas',
#   'fuerteventura',
#   'suministros'],
#  ['nuevas',
#   'salidas',
#   'aparcamientos',
#   'abierto',
#   'aena',
#   'direccion',
#   'aeropuerto',
#   'palma',
#   'mallorca',
#   'obras'],
#  ['contratacion',
#   'servicio',
#   'motocicletas',
#   'conductor',
#   'seguimiento',
#   'control',
#   'participantes',
#   'carreras',
#   'populares',
#   'circuito',
#   'sevilla',
#   'carrera',
#   'nocturna',
#   'sevilla',
#   'ruedas',
#   'anos',
#   'instituto',
#   'municipal',
#   'deportes',
#   'ayuntamiento',
#   'sevilla',
#   'abierto',
#   'simplificado',
#   'consejo',
#   'gobierno',
#   'instituto',
#   'municipal',
#   'deportes',
#   'ayuntamiento',
#   'sevilla',
#   'servicios'],
#  ['servicios',
#   'modernizacion',
#   'sistemas',
#   'corporativos',
#   'gestion',
#   'personal',
#   'ministerio',
#   'defensa',
#   'relacion',
#   'ejecucion',
#   'actuaciones',
#   'plan',
#   'recuperacion',
#   'transformacion',
#   'resiliencia',
#   'prtr',
#   'financiado',
#   'union',
#   'europea',
#   'nextgenerationeu',
#   'abierto',
#   'subdireccion',
#   'general',
#   'gestion',
#   'economica',
#   'servicios'],
#  ...]

# %%
any('kyocera' in sublist for sublist in corpus)
# Out:
# True

# %%
df.loc[849407, 'cleaned']
# Out:
# 'servicio formacion ambito ofimatica marco convocatoria formacion ocupacional oferta areas prioritarias foap negociado publicidad ayuntamiento mataro servicios'

# %% [markdown]
# ## Explicación de los hiperparámetros del word2vec

# %% [markdown]
# Understanding some of the parameters: https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
#
# To train the model earlier, we had to set some parameters. Now, let's try to understand what some of them mean. For reference, this is the command that we used to train the model.
#
# model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
#
# #### size
#
# The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.
#
# #### window
#
# The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.
#
# #### min_count
#
# Minimium frequency count of words. The model would ignore words that do not statisfy the min_count. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.
#
# #### workers
#
# How many threads to use behind the scenes?

# %% [markdown]
# ## Entrenamiento del modelo word2vec

# %%
# Create CBOW model
model_cbow = gensim.models.Word2Vec(corpus, 
                                    min_count = 10,
                                    vector_size = 100, 
                                    window = 5,
                                    workers = 10)

#model1.train(corpus, total_examples = len(corpus), epochs = 10)

# %%
# Create Skip Gram model
model_sw = gensim.models.Word2Vec(corpus, 
                                      min_count = 10, 
                                      vector_size = 100,
                                      window = 5, 
                                      sg = 1)

# %%
# Print results
print("Cosine similarity between 'abierto' " +
               "and 'simplificado' - Skip Gram : ",
    model_sw.wv.similarity('abierto', 'simplificado'))
# Out:
# Cosine similarity between 'abierto' and 'simplificado' - Skip Gram :  0.71698385

# %%
w1 = "mesa"
model_cbow.wv.most_similar(positive=w1)
# Out:
# [('senado', 0.7647478580474854),
#  ('diputados', 0.6881349086761475),
#  ('valencianes', 0.6643110513687134),
#  ('radiotransparente', 0.5713235139846802),
#  ('parlamento', 0.5668038725852966),
#  ('camara', 0.5308099389076233),
#  ('spect', 0.48241034150123596),
#  ('ujieres', 0.4539910554885864),
#  ('multifotonica', 0.4491378664970398),
#  ('estereotaxia', 0.4428333044052124)]

# %%
# Which one is the odd one out in this list?
model_cbow.wv.doesnt_match(["abierto","simplificado","silla"])
# Out:
# 'silla'

# %%
df.head(3)
# Out:
#    Identificador    Número de expediente  \
# 0        8689190          300/2021/00220
# 1        8723412           2021/066 PASS
# 2        8303894  77/IDE/2021/2021/O/128
#
#                                      Link licitación  \
# 0  https://contrataciondelestado.es/wps/poc?uri=d...
# 1  https://contrataciondelestado.es/wps/poc?uri=d...
# 2  https://contrataciondelestado.es/wps/poc?uri=d...
#
#                                  Objeto del Contrato      Estado  \
# 0  Escuela de deportes alternativos, para el fome...    Resuelta
# 1  Suministro (Suscripción) de licencias de softw...  Adjudicada
# 2  Instalación de envolvente en el Ayuntamiento d...    Resuelta
#
#   Vigente/Anulada/Archivada Tipo de procedimiento Tramitación  \
# 0                   VIGENTE  Abierto simplificado   Ordinaria
# 1                   VIGENTE  Abierto simplificado   Ordinaria
# 2                   VIGENTE  Abierto simplificado   Ordinaria
#
#   Forma de presentación de la oferta  \
# 0                        Electrónica
# 1                        Electrónica
# 2                        Electrónica
#
#                               Órgano de Contratación  ...  \
# 0                                 Distrito de Latina  ...
# 1  Presidencia de la Autoridad Independiente de R...  ...
# 2  Área de Fomento de la Diputación Provincial de...  ...
#
#   Identificador Adjudicatario de la licitación/lote  \
# 0                                         G82270489
# 1                                         B84852391
# 2                                         B06220818
#
#    Importe adjudicación sin impuestos licitación/lote Primera publicación  \
# 0                                            20000,0           2021-11-15
# 1                                           17656,32           2021-11-18
# 2                                            41200,0           2021-09-16
#
#   Fecha actualización Código Lugar de ejecución     Tipo Licitación  \
# 0          2021-12-30                     ES300  Licitación Directa
# 1          2021-12-30                     ES300  Licitación Directa
# 2          2021-12-30                     ES431  Licitación Directa
#
#              idioma                                          translate  \
# 0  Language.SPANISH  Escuela de deportes alternativos, para el fome...
# 1  Language.SPANISH  Suministro (Suscripción) de licencias de softw...
# 2  Language.SPANISH  Instalación de envolvente en el Ayuntamiento d...
#
#                                             analisis  \
# 0  Escuela de deportes alternativos, para el fome...
# 1  Suministro (Suscripcion) de licencias de softw...
# 2  Instalacion de envolvente en el Ayuntamiento d...
#
#                                              cleaned
# 0  escuela deportes alternativos fomento deporte ...
# 1  suministro suscripcion licencias software ofim...
# 2  instalacion envolvente ayuntamiento rena abier...
#
# [3 rows x 31 columns]

# %%
len(model_sw.wv)
# Out:
# 37054

# %%
model_sw.wv.index_to_key
# Out:
# ['abierto',
#  'servicios',
#  'suministros',
#  'servicio',
#  'suministro',
#  'simplificado',
#  'ayuntamiento',
#  'obras',
#  's',
#  'direccion',
#  'a',
#  'publicidad',
#  'negociado',
#  'general',
#  'marco',
#  'mantenimiento',
#  'acuerdo',
#  'junta',
#  'gobierno',
#  'i',
#  'contratacion',
#  'salud',
#  'alcaldia',
#  'd',
#  'contrato',
#  'seguridad',
#  'gestion',
#  'municipal',
#  'gerencia',
#  'centros',
#  'derivado',
#  'l',
#  'material',
#  'ajuntament',
#  'social',
#  'hospital',
#  'presidencia',
#  'provincial',
#  'centro',
#  'barcelona',
#  'proyecto',
#  'consejeria',
#  'sanitaria',
#  'm',
#  'instalacion',
#  'administracion',
#  'publica',
#  'ejecucion',
#  'lotes',
#  'mutua',
#  'diputacion',
#  'madrid',
#  'adquisicion',
#  'lote',
#  'destino',
#  'asistencia',
#  'area',
#  'local',
#  'agencia',
#  'instalaciones',
#  'limpieza',
#  'empresa',
#  'estatal',
#  'consejo',
#  'educacion',
#  'instituto',
#  'e',
#  'universidad',
#  'desarrollo',
#  'objeto',
#  'universitario',
#  'equipos',
#  'obra',
#  'sociedad',
#  'tecnica',
#  'san',
#  'sistema',
#  'transporte',
#  'per',
#  'colaboradora',
#  'publico',
#  'atencion',
#  'p',
#  'municipales',
#  'mejora',
#  'andaluz',
#  'prestacion',
#  'vehiculos',
#  'c',
#  'economicos',
#  'formacion',
#  'programa',
#  'mediante',
#  'jefatura',
#  'control',
#  'plataforma',
#  'cultura',
#  'realizacion',
#  'internas',
#  'calle',
#  'empleo',
#  'personal',
#  'sevilla',
#  'equipamiento',
#  'sant',
#  'normas',
#  'turismo',
#  'uso',
#  'apoyo',
#  'medio',
#  'red',
#  'patrimonial',
#  'asuntos',
#  'fundacion',
#  'materiales',
#  'integral',
#  'edificio',
#  'territorial',
#  'castilla',
#  'construccion',
#  'agua',
#  'sa',
#  'catalunya',
#  'santa',
#  'redaccion',
#  'nacional',
#  'privado',
#  'ciudad',
#  'edificios',
#  'director',
#  'sistemas',
#  'institut',
#  'plan',
#  'valencia',
#  'proteccion',
#  'publicos',
#  'trabajo',
#  'consorcio',
#  'dos',
#  'ambiente',
#  'concesion',
#  'leon',
#  'productos',
#  'parque',
#  'rectorado',
#  'reparacion',
#  'sociales',
#  'especial',
#  'medicamentos',
#  'procedimiento',
#  'renfe',
#  'espana',
#  'departamento',
#  'provincia',
#  'logistica',
#  'andalucia',
#  'delegacion',
#  'renovacion',
#  'malaga',
#  'explotacion',
#  'tecnicas',
#  'actividades',
#  'dependientes',
#  'asi',
#  'municipio',
#  'lot',
#  'conselleria',
#  'personas',
#  'consorci',
#  'economica',
#  'subdireccion',
#  'secretaria',
#  'mercantil',
#  'zona',
#  'hacienda',
#  'infraestructuras',
#  'serveis',
#  'u',
#  'cordoba',
#  'comunidad',
#  'dels',
#  'salut',
#  'vigilancia',
#  'pliego',
#  'amb',
#  'reforma',
#  'residuos',
#  'fase',
#  'pleno',
#  'distrito',
#  'la',
#  'coordinacion',
#  'aguas',
#  'administrativo',
#  'ano',
#  'adecuacion',
#  'delegada',
#  'gerente',
#  'varios',
#  'els',
#  'servei',
#  'arrendamiento',
#  'generalitat',
#  'licencias',
#  'conservacion',
#  'soporte',
#  'seccion',
#  'escolar',
#  'sanitario',
#  'civil',
#  'compras',
#  'mar',
#  'ambito',
#  'autonoma',
#  'alicante',
#  'ii',
#  'trabajos',
#  'dependencias',
#  'informacion',
#  'software',
#  'economico',
#  'cataluna',
#  'basado',
#  'central',
#  'real',
#  'sector',
#  'departament',
#  'sanitarios',
#  'fomento',
#  'covid',
#  'base',
#  'prevencion',
#  'mobiliario',
#  'tecnico',
#  'fabricacion',
#  'cadiz',
#  'valladolid',
#  'rehabilitacion',
#  'diferentes',
#  'jaen',
#  'sanidad',
#  'proyectos',
#  'oficina',
#  'almeria',
#  'gran',
#  'deporte',
#  'asturias',
#  'mancha',
#  'catala',
#  'economia',
#  'ampliacion',
#  'regimen',
#  't',
#  'licitacion',
#  'investigacion',
#  'deportes',
#  'tipo',
#  'policia',
#  'recogida',
#  'energia',
#  'concejalia',
#  'entidad',
#  'patrimonio',
#  'o',
#  'sostenible',
#  'alta',
#  'diversos',
#  'actuaciones',
#  'prescripciones',
#  'autoridad',
#  'granada',
#  'empresarial',
#  'promocion',
#  'portuaria',
#  'alcalde',
#  'escuela',
#  'espacios',
#  'incendios',
#  'alquiler',
#  'presente',
#  'acondicionamiento',
#  'contracte',
#  'canarias',
#  'abastecimiento',
#  'expediente',
#  'mayores',
#  'infantil',
#  'equipo',
#  'valenciana',
#  'bar',
#  'laboratorio',
#  'administrativa',
#  'vivienda',
#  'num',
#  'insular',
#  'seguro',
#  'murcia',
#  'defensa',
#  'aeropuerto',
#  'alumbrado',
#  'illes',
#  'badajoz',
#  'puesta',
#  'balears',
#  'alimentacion',
#  'parc',
#  'fungible',
#  'sustitucion',
#  'tratamiento',
#  'primaria',
#  'termino',
#  'elementos',
#  'acceso',
#  'zaragoza',
#  'mando',
#  'agricultura',
#  'maquinaria',
#  'necesarios',
#  'llobregat',
#  'interior',
#  'electrica',
#  'complejo',
#  'campo',
#  'condiciones',
#  'tenerife',
#  'organizacion',
#  'objecte',
#  'planta',
#  'feder',
#  'carretera',
#  'datos',
#  'correos',
#  'montaje',
#  'cursos',
#  'nuevo',
#  'plaza',
#  'compra',
#  'regional',
#  'canaria',
#  'adif',
#  'rural',
#  'recursos',
#  'publicas',
#  'fundacio',
#  'adscritos',
#  'logistico',
#  'dentro',
#  'territorio',
#  'calidad',
#  'anos',
#  'ministerio',
#  'puerto',
#  'emergencia',
#  'radio',
#  'diseno',
#  'unidad',
#  'saneamiento',
#  'universitat',
#  'comarcal',
#  'gestio',
#  'television',
#  'transformacion',
#  'unidades',
#  'aena',
#  'enajenacion',
#  'seguros',
#  'ics',
#  'preventivo',
#  'asepeyo',
#  'zonas',
#  'andaluza',
#  'correctivo',
#  'sede',
#  'girona',
#  'consell',
#  'galicia',
#  'huelva',
#  'tres',
#  'valles',
#  'igualdad',
#  'calles',
#  'comunicacion',
#  'medios',
#  'tramo',
#  'reactivos',
#  'pavimentacion',
#  'produccion',
#  'espanola',
#  'residencia',
#  'varias',
#  'agraria',
#  'y',
#  'paradores',
#  'actualizacion',
#  'infraestructura',
#  'salamanca',
#  'materia',
#  'sau',
#  'exclusivos',
#  'asesoramiento',
#  'sur',
#  'locales',
#  'implantacion',
#  'fondo',
#  'analisis',
#  'n',
#  'elaboracion',
#  'urbano',
#  'estacion',
#  'segun',
#  'vestuario',
#  'campana',
#  'vehiculo',
#  'laboral',
#  'industrial',
#  'impresion',
#  'palma',
#  'concello',
#  'comunidades',
#  'prorroga',
#  'nueva',
#  'exterior',
#  'operativo',
#  'fiestas',
#  'diversas',
#  'dia',
#  'centrales',
#  'digital',
#  'cesion',
#  'parte',
#  'linea',
#  'estudio',
#  'curso',
#  'propiedad',
#  'diverso',
#  'coruna',
#  'com',
#  'especifico',
#  'urbanizacion',
#  'profesional',
#  'infraestructures',
#  'rioja',
#  'caceres',
#  'necesario',
#  'fremap',
#  'castellon',
#  'deportivas',
#  'camino',
#  'do',
#  'justicia',
#  'via',
#  'grupo',
#  'b',
#  'adjudicacion',
#  'financiera',
#  'responsabilidad',
#  'ambiental',
#  'climatizacion',
#  'delegado',
#  'juan',
#  'intendencia',
#  'aire',
#  'actividad',
#  'medidas',
#  'informatica',
#  'viajeros',
#  'europeo',
#  'casa',
#  'octubre',
#  'modalidad',
#  'tributaria',
#  'superior',
#  'distribucion',
#  'tarragona',
#  'clave',
#  'periodo',
#  'equipamientos',
#  'empresas',
#  'penitenciario',
#  'necesidades',
#  'municipios',
#  'imparticion',
#  'cafeteria',
#  'cantabro',
#  'clinico',
#  'intendente',
#  'burgos',
#  'corporacion',
#  'toledo',
#  'aerea',
#  'canal',
#  'villa',
#  'sala',
#  'poblacion',
#  'costa',
#  'destinado',
#  'actuacion',
#  'telegrafos',
#  'cultural',
#  'carreteras',
#  'piscina',
#  'tramitacion',
#  'integrada',
#  'organismo',
#  'penitenciarios',
#  'energetica',
#  'caminos',
#  'movilidad',
#  'baja',
#  'cabildo',
#  'rio',
#  'contractacio',
#  'espacio',
#  'albacete',
#  'tragsa',
#  'ceuta',
#  'repuestos',
#  'derecho',
#  'profesionales',
#  'internacional',
#  'investigaciones',
#  'oficinas',
#  'accidentes',
#  'asistencial',
#  'autonomo',
#  'traves',
#  'ceip',
#  'hospitalario',
#  'emergencias',
#  'vinculados',
#  'carlos',
#  'natural',
#  'catalana',
#  'transportes',
#  'inspeccion',
#  'educativos',
#  'politicas',
#  'sabadell',
#  'ordenacion',
#  'redes',
#  'iii',
#  'informatico',
#  'comision',
#  'lleida',
#  'cuenca',
#  'ferrocarrils',
#  'en',
#  'municipals',
#  'integran',
#  'verano',
#  'deportivo',
#  'estaciones',
#  'entidades',
#  'acciones',
#  'umivale',
#  'especializada',
#  'movil',
#  'palencia',
#  'plazas',
#  'docentes',
#  'funcionamiento',
#  'aquest',
#  'cubierta',
#  'iluminacion',
#  'canario',
#  'diputacio',
#  'unica',
#  'realizar',
#  'tecnologia',
#  'eficiencia',
#  'presidente',
#  'mancomunidad',
#  'da',
#  'gijon',
#  'desmontaje',
#  'corporacio',
#  'consistente',
#  'guardia',
#  'basico',
#  'facultativa',
#  'aprovechamiento',
#  'mercado',
#  'extincion',
#  'correspondientes',
#  'aplicacion',
#  'mayor',
#  'norte',
#  'caracter',
#  'forestales',
#  'laboratorios',
#  'marcha',
#  'riesgos',
#  'restauracion',
#  'renting',
#  'bilbao',
#  'subministrament',
#  'mutual',
#  'sol',
#  'cantabria',
#  'cofinanciado',
#  'cruz',
#  'manteniment',
#  'museo',
#  'futbol',
#  'als',
#  'centre',
#  'principado',
#  'soria',
#  'comarca',
#  'intervencion',
#  'palmas',
#  'numero',
#  'papel',
#  'seguimiento',
#  'opcion',
#  'pontevedra',
#  'activa',
#  'pruebas',
#  'fisioterapia',
#  'mas',
#  'programas',
#  'flota',
#  'artes',
#  'centralizada',
#  'auditoria',
#  'viviendas',
#  'teatro',
#  'especiales',
#  'poligono',
#  'lanzarote',
#  'melilla',
#  'venta',
#  'creacion',
#  'parques',
#  'excmo',
#  'avila',
#  'comedor',
#  'planificacion',
#  'innovacion',
#  'pau',
#  'feria',
#  'aigua',
#  'restringido',
#  'telecomunicaciones',
#  'entorno',
#  'talleres',
#  'temporada',
#  'generales',
#  'cyclops',
#  'parcela',
#  'midat',
#  'extremadura',
#  'suelo',
#  'auxiliares',
#  'am',
#  'urbanos',
#  'acord',
#  'areas',
#  'mallorca',
#  'zamora',
#  'consultoria',
#  'projecte',
#  'individual',
#  'generalidad',
#  'urbanismo',
#  'cirugia',
#  'sito',
#  'informaticos',
#  'salvamento',
#  'retirada',
#  'cooperacion',
#  'nuevas',
#  'patronato',
#  'gas',
#  'protesis',
#  'juventud',
#  'maria',
#  'cartagena',
#  'marina',
#  'plec',
#  'reposicion',
#  'pls',
#  'exp',
#  'adaptacion',
#  'metro',
#  'aigues',
#  'distintos',
#  'vicepresidencia',
#  'foral',
#  'tgss',
#  'socials',
#  'tecnologias',
#  'principal',
#  'ejercito',
#  'ejecutivo',
#  'alcala',
#  'comunicaciones',
#  'pesca',
#  'web',
#  'dominio',
#  'farmacia',
#  'v',
#  'polideportivo',
#  'region',
#  'caracteristicas',
#  'ganaderia',
#  'accesos',
#  'playas',
#  'estudios',
#  'miguel',
#  'desinfeccion',
#  'aplicaciones',
#  'navarra',
#  'frente',
#  'avenida',
#  'usuarios',
#  'fraternidad',
#  'electronica',
#  'accesibilidad',
#  'cada',
#  'posterior',
#  'muprespa',
#  'refuerzo',
#  'montes',
#  'trabajadores',
#  'cuatro',
#  'infantiles',
#  'huesca',
#  'politecnica',
#  'reina',
#  'musica',
#  'culturales',
#  'electrico',
#  'armada',
#  'frontera',
#  'humano',
#  'torre',
#  'guadalajara',
#  'educacio',
#  'el',
#  'bienes',
#  'dividido',
#  'biblioteca',
#  'generico',
#  'diagnostico',
#  'remodelacion',
#  'senalizacion',
#  'lt',
#  'sierra',
#  'gt',
#  'situado',
#  'denominado',
#  'union',
#  'pel',
#  'pista',
#  'consumo',
#  'creu',
#  'vall',
#  'deportiva',
#  'subsecretaria',
#  'elche',
#  'can',
#  'tecnicos',
#  'lots',
#  'ruta',
#  'contenedores',
#  'treball',
#  'mejoras',
#  'ingenieria',
#  'pfea',
#  'campus',
#  'consejero',
#  'parcelas',
#  'mixto',
#  'puntos',
#  'revision',
#  'pacientes',
#  'baleares',
#  'aragon',
#  'destinados',
#  'colectivo',
#  'insercion',
#  'vial',
#  'segovia',
#  'residus',
#  'metropolitana',
#  'barrio',
#  'verdes',
#  'tension',
#  'cientificas',
#  'santiago',
#  'urbana',
#  'pabellon',
#  'obres',
#  'necesarias',
#  'maquinas',
#  'marca',
#  'contratos',
#  'tecniques',
#  'danos',
#  'combustible',
#  'almacenamiento',
#  'sebastian',
#  'ejercicio',
#  'participacion',
#  'cocina',
#  'menores',
#  'universal',
#  'pk',
#  'lugo',
#  'imagen',
#  'enfermedades',
#  'riesgo',
#  'comite',
#  'accion',
#  'vigo',
#  'velocidad',
#  'monte',
#  'getafe',
#  'alto',
#  'correspondiente',
#  'difusion',
#  'comunitat',
#  'inss',
#  'teruel',
#  'bajo',
#  'bizkaia',
#  'viaria',
#  'ejecutiva',
#  'escuelas',
#  'as',
#  'primera',
#  'firme',
#  'garantia',
#  'marbella',
#  'vias',
#  'modernizacion',
#  'internos',
#  'iv',
#  'riojano',
#  'accesorios',
#  'normativa',
#  'militar',
#  'siguientes',
#  'entrega',
#  'amp',
#  'mascarillas',
#  'joan',
#  'trafico',
#  'fuerteventura',
#  'ambulatorio',
#  'eventos',
#  'mercados',
#  'referencia',
#  'maz',
#  'gases',
#  'documentacion',
#  'bienestar',
#  'hidrografica',
#  'juridico',
#  'rey',
#  'r',
#  'polizas',
#  'oviedo',
#  'cabo',
#  'nuevos',
#  'situacion',
#  'distintas',
#  'terrassa',
#  'segura',
#  'auxiliar',
#  'molina',
#  'tauli',
#  'organismos',
#  'fondos',
#  'higiene',
#  'particulares',
#  'piscinas',
#  'agrupacion',
#  'motivo',
#  'escolares',
#  'operaciones',
#  'titularidad',
#  'sucesivo',
#  'deteccion',
#  'ies',
#  'programacion',
#  'deposito',
#  'es',
#  'familia',
#  'materias',
#  'un',
#  'puente',
#  'fernando',
#  'terrestre',
#  'autonomos',
#  'comercio',
#  'utilizacion',
#  'establecimientos',
#  'consumibles',
#  'jardineria',
#  'dinamizacion',
#  'frutas',
#  'forma',
#  'cuerpo',
#  'confederacion',
#  'muestras',
#  'f',
#  'administrativas',
#  'evaluacion',
#  'poliza',
#  'edar',
#  'familias',
#  'licencia',
#  'urgente',
#  'industriales',
#  'incluidas',
#  'formativas',
#  'isla',
#  'vida',
#  'ropa',
#  'monitorizacion',
#  'jose',
#  'paseo',
#  'incluidos',
#  'concurso',
#  'expte',
#  'potable',
#  'ocupacion',
#  'division',
#  'hospitales',
#  'traslado',
#  'sostenibilidad',
#  'discapacidad',
#  'execucio',
#  'politica',
#  'dotacion',
#  'industria',
#  'jardines',
#  'criterios',
#  'asociacion',
#  'verduras',
#  'ambulatoria',
#  'ordenadores',
#  'turistica',
#  'analiticas',
#  'aparcamiento',
#  'balear',
#  'aparatos',
#  'seleccion',
#  'prestacio',
#  'celebracion',
#  'portatiles',
#  'laborales',
#  'calefaccion',
#  'uniformidad',
#  'paz',
#  'sanitari',
#  'primas',
#  'cobertura',
#  'dispositivos',
#  'carga',
#  'pavimento',
#  'existentes',
#  'constructivo',
#  'reyes',
#  'diciembre',
#  'taller',
#  'font',
#  'cd',
#  'logrono',
#  'privativo',
#  'ubicado',
#  'prestaciones',
#  'sl',
#  'inmuebles',
#  'suscripcion',
#  'juridica',
#  'pedro',
#  'edicion',
#  'madera',
#  'electricas',
#  'islas',
#  'ferrol',
#  'viladecans',
#  'hardware',
#  'ourense',
#  'historico',
#  'enaire',
#  'senora',
#  'k',
#  'nivel',
#  'isabel',
#  'unico',
#  'anexo',
#  'derivados',
#  'prat',
#  'tecnologico',
#  'estrategia',
#  'conexion',
#  ...]

# %%
model_cbow.wv.vectors.shape
# Out:
# (37054, 100)

# %% [markdown]
# ## Guardado del modelo para visualización
#
# https://radimrehurek.com/gensim/scripts/word2vec2tensor.html
#
# python -m gensim.scripts.word2vec2tensor -i .\word2vec.model -o .\tensorboard\

# %%
model_sw.wv.save_word2vec_format("word2vec_sw.model")
model_cbow.wv.save_word2vec_format("word2vec_cbow.model")

# %% [markdown]
# ## Asignación de pesos a las licitaciones

# %%
model = model_sw

# %%
df['avg word2vec'] = ''

# %%
# Generate the average word2vec for the each book description

def vectors(x):
    
    # Creating a list for storing the vectors (description into vectors)
    global word_embeddings
    word_embeddings = []
    df_cleaned = []

    # Reading the each book description 
    for idx, line in x.iterrows():
        avgword2vec = None
        count = 0
        for word in line['cleaned'].split():
            if word in model.wv:
                count += 1
                if avgword2vec is None:
                    avgword2vec = model.wv[word]
                else:
                    avgword2vec = avgword2vec + model.wv[word]

        if avgword2vec is not None:
            avgword2vec = avgword2vec / count
            #print([avgword2vec.tolist()])

            x.at[idx, 'avg word2vec'] = avgword2vec
            #word_embeddings.append(avgword2vec)
            #df_cleaned.append(line)
            
    #df_ = pd.DataFrame(df_cleaned)
    #df_ = df_.rename(columns = {0: 'title'})
    
    return x

# %%
df_ = vectors(df)

# %%
df_.head(3)
# Out:
#    Identificador    Número de expediente  \
# 0        8689190          300/2021/00220
# 1        8723412           2021/066 PASS
# 2        8303894  77/IDE/2021/2021/O/128
#
#                                      Link licitación  \
# 0  https://contrataciondelestado.es/wps/poc?uri=d...
# 1  https://contrataciondelestado.es/wps/poc?uri=d...
# 2  https://contrataciondelestado.es/wps/poc?uri=d...
#
#                                  Objeto del Contrato      Estado  \
# 0  Escuela de deportes alternativos, para el fome...    Resuelta
# 1  Suministro (Suscripción) de licencias de softw...  Adjudicada
# 2  Instalación de envolvente en el Ayuntamiento d...    Resuelta
#
#   Vigente/Anulada/Archivada Tipo de procedimiento Tramitación  \
# 0                   VIGENTE  Abierto simplificado   Ordinaria
# 1                   VIGENTE  Abierto simplificado   Ordinaria
# 2                   VIGENTE  Abierto simplificado   Ordinaria
#
#   Forma de presentación de la oferta  \
# 0                        Electrónica
# 1                        Electrónica
# 2                        Electrónica
#
#                               Órgano de Contratación  ...  \
# 0                                 Distrito de Latina  ...
# 1  Presidencia de la Autoridad Independiente de R...  ...
# 2  Área de Fomento de la Diputación Provincial de...  ...
#
#   Importe adjudicación sin impuestos licitación/lote  Primera publicación  \
# 0                                            20000,0           2021-11-15
# 1                                           17656,32           2021-11-18
# 2                                            41200,0           2021-09-16
#
#   Fecha actualización Código Lugar de ejecución     Tipo Licitación  \
# 0          2021-12-30                     ES300  Licitación Directa
# 1          2021-12-30                     ES300  Licitación Directa
# 2          2021-12-30                     ES431  Licitación Directa
#
#              idioma                                          translate  \
# 0  Language.SPANISH  Escuela de deportes alternativos, para el fome...
# 1  Language.SPANISH  Suministro (Suscripción) de licencias de softw...
# 2  Language.SPANISH  Instalación de envolvente en el Ayuntamiento d...
#
#                                             analisis  \
# 0  Escuela de deportes alternativos, para el fome...
# 1  Suministro (Suscripcion) de licencias de softw...
# 2  Instalacion de envolvente en el Ayuntamiento d...
#
#                                              cleaned  \
# 0  escuela deportes alternativos fomento deporte ...
# 1  suministro suscripcion licencias software ofim...
# 2  instalacion envolvente ayuntamiento rena abier...
#
#                                         avg word2vec
# 0  [0.012540068, 0.008312313, -0.037487954, -0.07...
# 1  [0.07913456, 0.25526994, -0.17649616, 0.204690...
# 2  [-0.09953443, -0.11866342, -0.17670447, 0.0230...
#
# [3 rows x 32 columns]

# %%
df_.loc[df_['Identificador Adjudicatario de la licitación/lote'] == 'B38944864']
# Out:
#         Identificador            Número de expediente  \
# 2685          8430166                       1560/2021
# 29187         8442249                          8/2021
# 29792         8108023                          6/2021
# 54994         7813691                 CONTR 2021/9310
# 66835         8121135                   DGMCS006/2021
# 82585         7433712                          1/2021
# 82586         7433712                          1/2021
# 88574         7401206                          2/2021
# 117506        3602378                  EJ/2019/000028
# 152231        5445771                        A-3/2020
# 162696        6159389  L03380011- LA0001757-ED-4/2020
#
#                                           Link licitación  \
# 2685    https://contrataciondelestado.es/wps/poc?uri=d...
# 29187   https://contrataciondelestado.es/wps/poc?uri=d...
# 29792   https://contrataciondelestado.es/wps/poc?uri=d...
# 54994   https://contrataciondelestado.es/wps/poc?uri=d...
# 66835   https://contrataciondelestado.es/wps/poc?uri=d...
# 82585   https://contrataciondelestado.es/wps/poc?uri=d...
# 82586   https://contrataciondelestado.es/wps/poc?uri=d...
# 88574   https://contrataciondelestado.es/wps/poc?uri=d...
# 117506  https://contrataciondelestado.es/wps/poc?uri=d...
# 152231  https://contrataciondelestado.es/wps/poc?uri=d...
# 162696  https://contrataciondelestado.es/wps/poc?uri=d...
#
#                                       Objeto del Contrato      Estado  \
# 2685    Elaboración de una herramienta de visualizació...  Adjudicada
# 29187   Asistencia técnica en la elaboración de indica...    Resuelta
# 29792   Asistencia técnica estadística para el Proyect...    Resuelta
# 54994   Asistencia técnica a la producción estadística...    Resuelta
# 66835   Servicio de consultoría y asistencia técnica p...    Resuelta
# 82585   Asistencia técnica a la producción estadística...    Resuelta
# 82586   Asistencia técnica a la producción estadística...    Resuelta
# 88574   Asistencia técnica al Proyecto de la Estadísti...    Resuelta
# 117506   El contrato tiene por objeto la prestación de...  Adjudicada
# 152231  Contratación de los servicios de actividades d...  Adjudicada
# 162696  PIALTE 2020/2021 (ED 4-2020). El objeto del co...    Resuelta
#
#        Vigente/Anulada/Archivada Tipo de procedimiento Tramitación  \
# 2685                     VIGENTE  Abierto simplificado   Ordinaria
# 29187                    VIGENTE  Abierto simplificado   Ordinaria
# 29792                    VIGENTE               Abierto   Ordinaria
# 54994                    VIGENTE               Abierto   Ordinaria
# 66835                    VIGENTE  Abierto simplificado   Ordinaria
# 82585                    VIGENTE               Abierto   Ordinaria
# 82586                    VIGENTE               Abierto   Ordinaria
# 88574                    VIGENTE               Abierto   Ordinaria
# 117506                   VIGENTE               Abierto   Ordinaria
# 152231                   VIGENTE               Abierto   Ordinaria
# 162696                   VIGENTE               Abierto   Ordinaria
#
#        Forma de presentación de la oferta  \
# 2685                          Electrónica
# 29187                         Electrónica
# 29792                         Electrónica
# 54994                         Electrónica
# 66835                         Electrónica
# 82585                         Electrónica
# 82586                         Electrónica
# 88574                         Electrónica
# 117506                        Electrónica
# 152231                        Electrónica
# 162696                        Electrónica
#
#                                    Órgano de Contratación  ...  \
# 2685    Presidencia del Ente Público Empresarial Puert...  ...
# 29187   Director del Instituto Canario de Estadística ...  ...
# 29792   Director del Instituto Canario de Estadística ...  ...
# 54994       Instituto de Estadística de las Illes Balears  ...
# 66835   Dirección General de Modernización y Calidad d...  ...
# 82585   Director del Instituto Canario de Estadística ...  ...
# 82586   Director del Instituto Canario de Estadística ...  ...
# 88574   Director del Instituto Canario de Estadística ...  ...
# 117506  Junta de Gobierno del Ayuntamiento de Santa Cr...  ...
# 152231  Presidencia Organismo Autónomo de Museos y Cen...  ...
# 162696  Consejo de Gobierno Insular del Cabildo Insula...  ...
#
#        Resultado licitación/lote  \
# 2685                  Adjudicado
# 29187                 Adjudicado
# 29792                 Adjudicado
# 54994                 Adjudicado
# 66835                 Adjudicado
# 82585                 Adjudicado
# 82586                 Adjudicado
# 88574                 Adjudicado
# 117506                Adjudicado
# 152231                Adjudicado
# 162696                Adjudicado
#
#         Identificador Adjudicatario de la licitación/lote  \
# 2685                                            B38944864
# 29187                                           B38944864
# 29792                                           B38944864
# 54994                                           B38944864
# 66835                                           B38944864
# 82585                                           B38944864
# 82586                                           B38944864
# 88574                                           B38944864
# 117506                                          B38944864
# 152231                                          B38944864
# 162696                                          B38944864
#
#        Importe adjudicación sin impuestos licitación/lote Primera publicación  \
# 2685                                              22500,0          2021-10-07
# 29187                                             84000,0          2021-10-08
# 29792                                            290000,0          2021-08-05
# 54994                                            90904,58          2021-07-02
# 66835                                             45500,0          2021-08-06
# 82585                                            702000,0          2021-04-25
# 82586                                            624000,0          2021-04-25
# 88574                                            176000,0          2021-04-21
# 117506                                           655000,0          2019-05-20
# 152231                                           82751,27          2020-08-10
# 162696                                           32092,36          2020-07-22
#
#        Fecha actualización Código Lugar de ejecución     Tipo Licitación  \
# 2685            2021-12-29                      ES70  Licitación Directa
# 29187           2021-11-23                      ES70  Licitación Directa
# 29792           2021-11-23                      ES70  Licitación Directa
# 54994           2021-10-06                     ES532  Licitación Directa
# 66835           2021-09-10                     ES709  Licitación Directa
# 82585           2021-07-30                      ES70  Licitación Directa
# 82586           2021-07-30                      ES70  Licitación Directa
# 88574           2021-07-16                      ES70  Licitación Directa
# 117506          2021-05-13                     ES709  Licitación Directa
# 152231          2021-02-12                     ES709  Licitación Directa
# 162696          2021-01-18                      ES70  Licitación Directa
#
#                                                  analisis  \
# 2685    Elaboracion de una herramienta de visualizacio...
# 29187   Asistencia tecnica en la elaboracion de indica...
# 29792   Asistencia tecnica estadistica para el Proyect...
# 54994   Asistencia tecnica a la produccion estadistica...
# 66835   Servicio de consultoria y asistencia tecnica p...
# 82585   Asistencia tecnica a la produccion estadistica...
# 82586   Asistencia tecnica a la produccion estadistica...
# 88574   Asistencia tecnica al Proyecto de la Estadisti...
# 117506   El contrato tiene por objeto la prestacion de...
# 152231  Contratacion de los servicios de actividades d...
# 162696  PIALTE 2020/2021 (ED 4-2020). El objeto del co...
#
#                                                   cleaned  \
# 2685    elaboracion herramienta visualizacion datos at...
# 29187   asistencia tecnica elaboracion indicadores req...
# 29792   asistencia tecnica estadistica proyecto medcoa...
# 54994   asistencia tecnica produccion estadistica inst...
# 66835   servicio consultoria asistencia tecnica defini...
# 82585   asistencia tecnica produccion estadistica inst...
# 82586   asistencia tecnica produccion estadistica inst...
# 88574   asistencia tecnica proyecto estadistica poblac...
# 117506  contrato objeto prestacion servicios apertura ...
# 152231  contratacion servicios actividades didacticas ...
# 162696  pialte 2020 2021 ed 4 2020 objeto contrato ser...
#
#                                              avg word2vec
# 2685    [-0.084173925, -0.03299803, -0.24019097, -0.06...
# 29187   [0.03202313, 0.31714207, -0.3279275, -0.054686...
# 29792   [-0.1433087, 0.15215789, -0.28989643, 0.014293...
# 54994   [-0.10759709, 0.24977857, -0.38225928, 0.07332...
# 66835   [0.014282397, 0.123506434, -0.30014586, -0.028...
# 82585   [-0.100316934, 0.27400094, -0.33375058, 0.0646...
# 82586   [-0.100316934, 0.27400094, -0.33375058, 0.0646...
# 88574   [-0.04111858, 0.05675525, -0.25336602, 0.07226...
# 117506  [0.28186494, -0.13018064, -0.15886948, 0.07237...
# 152231  [0.11920337, -0.18525346, -0.27225515, -0.0668...
# 162696  [0.10865477, 0.042923126, -0.3469763, -0.12967...
#
# [11 rows x 30 columns]

# %%
df_.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286014 entries, 0 to 833755
# Columns: 30 entries, Identificador to avg word2vec
# dtypes: int64(3), object(27)
# memory usage: 75.7+ MB

# %%
# Recommending the Top 5 similar books

def recommendations(df_, df_index):
    
    # finding cosine similarity for the vectors

    cosine_similarities = cosine_similarity(df_.loc[df_index, 'avg word2vec'].reshape(1,-1), 
                                            df_['avg word2vec'].values.tolist())
    
    df_['cosine'] = cosine_similarities.T
         
    #idx = df_.loc[df_['title'] == title].index.values[0]
    #sim_scores = list(enumerate(cosine_similarities[idx]))
    #sim_scores = sorted(cosine_similarities, key = lambda x: x[1], reverse = True)
    df_ = df_.sort_values(by = 'cosine', ascending = False)
    #sim_scores = sim_scores[1:6]
    #book_indices = [i[0] for i in sim_scores]
    #recommend = df_.iloc[1:6]
    
    return df_

# %%
rec = recommendations(df_, 2685)

# %%
for i in rec.index.values[:6]:
    print(rec.loc[i, 'Link licitación'])
    print(rec.loc[i, 'cosine'])
# Out:
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=GAYaOpLvG2Muf4aBO%2BvQlQ%3D%3D
# 0.9999999
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=Rufi8oEnjtfnSoTX3z%2F7wA%3D%3D
# 0.965695
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=ZQabzBretzGXQV0WE7lYPw%3D%3D
# 0.8993915
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=H4PPS7MKWtirz3GQd5r6SQ%3D%3D
# 0.8980014
# http://www.gobiernodecanarias.org/perfildelcontratante/apipublica/anuncios-licitacion.html?licitacion=67259
# 0.8979521
# http://www.gobiernodecanarias.org/perfildelcontratante/apipublica/anuncios-licitacion.html?licitacion=67260
# 0.8979521

# %%
for i in rec.index.values[:6]:
    print(rec.loc[i, 'Link licitación'])
    print(rec.loc[i, 'cosine'])
# Out:
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=GAYaOpLvG2Muf4aBO%2BvQlQ%3D%3D
# 0.9999998
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=Rufi8oEnjtfnSoTX3z%2F7wA%3D%3D
# 0.9131579
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=ZQabzBretzGXQV0WE7lYPw%3D%3D
# 0.87696975
# http://www.madrid.org/cs/Satellite?op2=PCON&idPagina=1204201624785&c=CM_ConvocaPrestac_FA&pagename=PortalContratacion%2FPage%2FPCON_contratosPublicos&language=es&idConsejeria=1109266187224&cid=1354874142911
# 0.87384385
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=bvpkAhokotVvYnTkQN0%2FZA%3D%3D
# 0.87178814
# http://www.madrid.org/cs/Satellite?op2=PCON&idPagina=1204201624785&c=CM_ConvocaPrestac_FA&pagename=PortalContratacion%2FPage%2FPCON_contratosPublicos&language=es&idConsejeria=1109266187224&cid=1354896231181
# 0.8663601

# %%
for i in rec.index.values[:6]:
    print(rec.loc[i, 'Link licitación'])
    print(rec.loc[i, 'cosine'])
# Out:
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=GAYaOpLvG2Muf4aBO%2BvQlQ%3D%3D
# 0.99999994
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=Rufi8oEnjtfnSoTX3z%2F7wA%3D%3D
# 0.9799895
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=ZQabzBretzGXQV0WE7lYPw%3D%3D
# 0.9443207
# https://www.contratosdegalicia.gal/licitacion?N=803423
# 0.9369464
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=H4PPS7MKWtirz3GQd5r6SQ%3D%3D
# 0.9362494
# https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=zm2dEKoeP66XQV0WE7lYPw%3D%3D
# 0.9356841
